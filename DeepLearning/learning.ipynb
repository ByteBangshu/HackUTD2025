# %%
# Create dataframe of data from csv plan. 
import pandas as pd
df: pd.DataFrame = pd.read_csv("toyota.csv")
df
# Out:
#               model  year  price transmission  mileage  fuelType   mpg  \
# 0              GT86  2016  16000       Manual    24089  Gasoline  36.2
# 1              GT86  2017  15995       Manual    18615  Gasoline  36.2
# 2              GT86  2015  13998       Manual    27469  Gasoline  36.2
# 3              GT86  2017  18998       Manual    14736  Gasoline  36.2
# 4              GT86  2017  17498       Manual    36284  Gasoline  36.2
# ...             ...   ...    ...          ...      ...       ...   ...
# 6270             IQ  2011   5500    Automatic    30000  Gasoline  58.9
# 6271  Urban Cruiser  2011   4985       Manual    36154  Gasoline  50.4
# 6272  Urban Cruiser  2012   4995       Manual    46000    Diesel  57.6
# 6273  Urban Cruiser  2011   3995       Manual    60700  Gasoline  50.4
# 6274  Urban Cruiser  2011   4495       Manual    45128  Gasoline  50.4
#
#       finance_monthly  lease_monthly  horsepower
# 0              292.25         261.23         197
# 1              292.16         261.16         197
# 2              255.68         231.06         197
# 3              347.01         306.43         197
# 4              319.61         283.82         197
# ...               ...            ...         ...
# 6270           100.46         102.96          68
# 6271            91.05          95.19         100
# 6272            91.24          95.34          90
# 6273            72.97          80.27         100
# 6274            82.10          87.81         100
#
# [6275 rows x 10 columns]

# %%
# declaring classes
classes: list[str] = []
# Determine what the pandas Iterator object looks like
for i in df["model"].unique():
  classes.append(i)
classes
# Out:
# ['GT86',
#  'Corolla',
#  'RAV4',
#  'Yaris',
#  'Auris',
#  'Aygo',
#  'C-HR',
#  'Prius',
#  'Avensis',
#  'Verso',
#  'Hilux',
#  'Land Cruiser',
#  'Supra',
#  'IQ',
#  'Urban Cruiser']

# %%
# Show there are 4 transmission types
transmissions: list[str] = []
# Determine what the pandas Iterator object looks like
for i in df["transmission"].unique():
  transmissions.append(i)
transmissions
# Out:
# ['Manual', 'Automatic', 'Semi-Auto', 'Other']

# %%
import pandas as pd
df: pd.DataFrame = pd.read_csv('toyota.csv')
temp_mixed_list = []
recommended_models = dict()
for index, row in df.iterrows():
          temp_mixed_list.append((row['year']))
          temp_mixed_list.append((row['price']))
          temp_mixed_list.append((row['transmission']))
          temp_mixed_list.append((row['mileage']))
          temp_mixed_list.append((row['fuelType']))
          temp_mixed_list.append((row['mpg']))
          temp_mixed_list.append((row['finance_monthly']))
          temp_mixed_list.append((row['lease_monthly']))
          temp_mixed_list.append((row['horsepower']))
          recommended_models[tuple(temp_mixed_list)] = (row['model'])
          temp_mixed_list.clear()
recommended_models
# Out:
# {(2016, 16000, 'Manual', 24089, 'Gasoline', 36.2, 292.25, 261.23, 197): 'GT86',
#  (2017, 15995, 'Manual', 18615, 'Gasoline', 36.2, 292.16, 261.16, 197): 'GT86',
#  (2015, 13998, 'Manual', 27469, 'Gasoline', 36.2, 255.68, 231.06, 197): 'GT86',
#  (2017, 18998, 'Manual', 14736, 'Gasoline', 36.2, 347.01, 306.43, 197): 'GT86',
#  (2017, 17498, 'Manual', 36284, 'Gasoline', 36.2, 319.61, 283.82, 197): 'GT86',
#  (2017, 15998, 'Manual', 26919, 'Gasoline', 36.2, 292.21, 261.2, 197): 'GT86',
#  (2017, 18522, 'Manual', 10456, 'Gasoline', 36.2, 338.31, 299.25, 197): 'GT86',
#  (2017, 18995, 'Manual', 12340, 'Gasoline', 36.2, 346.95, 306.38, 197): 'GT86',
#  (2020, 27998, 'Manual', 516, 'Gasoline', 33.2, 511.4, 426.31, 197): 'GT86',
#  (2016, 13990, 'Manual', 37999, 'Gasoline', 36.2, 255.53, 230.94, 197): 'GT86',
#  (2013, 10495, 'Manual', 72000, 'Gasoline', 36.2, 191.7, 178.25, 197): 'GT86',
#  (2017, 17990, 'Manual', 12597, 'Gasoline', 36.2, 328.6, 291.23, 197): 'GT86',
#  (2017, 16995, 'Manual', 36100, 'Gasoline', 36.2, 310.42, 276.23, 197): 'GT86',
#  (2019, 23995, 'Manual', 995, 'Gasoline', 33.2, 438.28, 381.75, 197): 'GT86',
#  (2018, 18498, 'Manual', 35228, 'Gasoline', 36.2, 337.87, 298.89, 197): 'GT86',
#  (2019, 23980, 'Manual', 1751, 'Gasoline', 33.2, 438.01, 381.53, 197): 'GT86',
#  (2017, 17995, 'Manual', 16444, 'Gasoline', 36.2, 328.69, 291.31, 197): 'GT86',
#  (2014, 12998, 'Manual', 25499, 'Gasoline', 36.2, 237.41, 215.98, 197): 'GT86',
#  (2019,
#   23495,
#   'Automatic',
#   3934,
#   'Gasoline',
#   32.8,
#   429.15,
#   374.22,
#   197): 'GT86',
#  (2019, 25780, 'Manual', 5123, 'Gasoline', 33.2, 470.88, 408.66, 197): 'GT86',
#  (2020,
#   26995,
#   'Semi-Auto',
#   1500,
#   'Gasoline',
#   32.8,
#   493.08,
#   411.76,
#   197): 'GT86',
#  (2019, 23998, 'Semi-Auto', 913, 'Gasoline', 32.8, 438.34, 381.8, 197): 'GT86',
#  (2019, 26995, 'Manual', 2680, 'Gasoline', 33.2, 493.08, 426.98, 197): 'GT86',
#  (2017, 17000, 'Manual', 14345, 'Gasoline', 36.2, 310.51, 276.31, 197): 'GT86',
#  (2018, 19995, 'Manual', 15525, 'Gasoline', 36.2, 365.22, 321.46, 197): 'GT86',
#  (2020, 31000, 'Manual', 3000, 'Gasoline', 33.2, 566.23, 469.87, 197): 'GT86',
#  (2016,
#   15995,
#   'Semi-Auto',
#   19460,
#   'Gasoline',
#   39.8,
#   292.16,
#   261.16,
#   197): 'GT86',
#  (2018, 18490, 'Manual', 31231, 'Gasoline', 36.2, 337.73, 298.77, 197): 'GT86',
#  (2020, 24990, 'Manual', 339, 'Gasoline', 33.2, 456.45, 382.66, 197): 'GT86',
#  (2015, 13981, 'Manual', 30500, 'Gasoline', 36.2, 255.37, 230.8, 197): 'GT86',
#  (2015, 13991, 'Manual', 38126, 'Gasoline', 36.2, 255.55, 230.95, 197): 'GT86',
#  (2019,
#   27060,
#   'Automatic',
#   3348,
#   'Gasoline',
#   32.8,
#   494.26,
#   427.96,
#   197): 'GT86',
#  (2018, 20695, 'Manual', 5260, 'Gasoline', 36.2, 378.0, 332.01, 197): 'GT86',
#  (2019, 25999, 'Manual', 100, 'Gasoline', 33.2, 474.88, 411.96, 197): 'GT86',
#  (2013, 11575, 'Manual', 50584, 'Gasoline', 36.2, 211.42, 194.53, 197): 'GT86',
#  (2017, 20995, 'Manual', 6445, 'Gasoline', 36.2, 383.48, 336.53, 197): 'GT86',
#  (2014, 14999, 'Manual', 18389, 'Gasoline', 36.2, 273.96, 246.15, 197): 'GT86',
#  (2019,
#   27000,
#   'Semi-Auto',
#   100,
#   'Gasoline',
#   32.8,
#   493.17,
#   427.05,
#   197): 'GT86',
#  (2016, 15000, 'Manual', 28321, 'Gasoline', 36.2, 273.98, 246.16, 197): 'GT86',
#  (2019,
#   22200,
#   'Semi-Auto',
#   16241,
#   'Gasoline',
#   32.8,
#   405.49,
#   354.69,
#   197): 'GT86',
#  (2019, 24990, 'Manual', 3150, 'Gasoline', 33.2, 456.45, 396.75, 197): 'GT86',
#  (2019, 25995, 'Manual', 8912, 'Gasoline', 33.2, 474.81, 411.9, 197): 'GT86',
#  (2017, 19500, 'Manual', 9639, 'Gasoline', 36.2, 356.18, 313.99, 197): 'GT86',
#  (2017, 18250, 'Manual', 20219, 'Gasoline', 36.2, 333.35, 295.15, 197): 'GT86',
#  (2019, 23995, 'Manual', 1557, 'Gasoline', 33.2, 438.28, 381.75, 197): 'GT86',
#  (2016, 17500, 'Manual', 14000, 'Gasoline', 36.2, 319.65, 283.85, 197): 'GT86',
#  (2019, 23997, 'Manual', 4500, 'Gasoline', 33.2, 438.32, 381.78, 197): 'GT86',
#  (2017, 17102, 'Manual', 21000, 'Gasoline', 36.2, 312.38, 277.85, 197): 'GT86',
#  (2019, 24995, 'Manual', 2488, 'Gasoline', 33.2, 456.55, 396.83, 197): 'GT86',
#  (2017, 19995, 'Manual', 26000, 'Gasoline', 36.2, 365.22, 321.46, 197): 'GT86',
#  (2020, 29769, 'Manual', 999, 'Gasoline', 33.2, 543.75, 452.01, 197): 'GT86',
#  (2019, 25850, 'Manual', 4442, 'Gasoline', 33.2, 472.16, 409.72, 197): 'GT86',
#  (2014, 13495, 'Manual', 24667, 'Gasoline', 36.2, 246.49, 223.47, 197): 'GT86',
#  (2017,
#   18495,
#   'Semi-Auto',
#   13930,
#   'Gasoline',
#   39.8,
#   337.82,
#   298.84,
#   197): 'GT86',
#  (2020, 25499, 'Manual', 614, 'Gasoline', 33.2, 465.75, 390.05, 197): 'GT86',
#  (2017, 18621, 'Manual', 18544, 'Gasoline', 36.2, 340.12, 300.74, 197): 'GT86',
#  (2019, 25121, 'Manual', 7056, 'Gasoline', 33.2, 458.85, 398.73, 197): 'GT86',
#  (2017, 17500, 'Manual', 11898, 'Gasoline', 36.2, 319.65, 283.85, 197): 'GT86',
#  (2013,
#   11599,
#   'Automatic',
#   28335,
#   'Gasoline',
#   39.8,
#   211.86,
#   194.89,
#   197): 'GT86',
#  (2017, 17249, 'Manual', 10089, 'Gasoline', 36.2, 315.06, 280.06, 197): 'GT86',
#  (2020, 25995, 'Manual', 3250, 'Gasoline', 33.2, 474.81, 397.25, 197): 'GT86',
#  (2014, 13000, 'Manual', 39761, 'Gasoline', 36.2, 237.45, 216.01, 197): 'GT86',
#  (2017, 17250, 'Manual', 19420, 'Gasoline', 36.2, 315.08, 280.08, 197): 'GT86',
#  (2019, 27950, 'Manual', 489, 'Gasoline', 33.2, 510.52, 441.37, 197): 'GT86',
#  (2020, 27995, 'Manual', 1055, 'Gasoline', 33.2, 511.34, 426.27, 197): 'GT86',
#  (2016, 13999, 'Manual', 19987, 'Gasoline', 36.2, 255.7, 231.07, 197): 'GT86',
#  (2012,
#   9995,
#   'Automatic',
#   74599,
#   'Gasoline',
#   39.8,
#   182.56,
#   170.71,
#   197): 'GT86',
#  (2015,
#   10499,
#   'Automatic',
#   81206,
#   'Gasoline',
#   39.8,
#   191.77,
#   178.31,
#   197): 'GT86',
#  (2012, 11995, 'Manual', 53000, 'Gasoline', 36.2, 219.09, 200.86, 197): 'GT86',
#  (2015, 13495, 'Manual', 49000, 'Gasoline', 36.2, 246.49, 223.47, 197): 'GT86',
#  (2019,
#   24990,
#   'Automatic',
#   4000,
#   'Gasoline',
#   32.8,
#   456.45,
#   396.75,
#   197): 'GT86',
#  (2017, 19500, 'Manual', 6725, 'Gasoline', 36.2, 356.18, 313.99, 197): 'GT86',
#  (2020, 28000, 'Manual', 650, 'Gasoline', 33.2, 511.43, 426.34, 197): 'GT86',
#  (2019,
#   20250,
#   'Automatic',
#   7445,
#   'Hybrid',
#   85.6,
#   369.88,
#   325.3,
#   122): 'Corolla',
#  (2020,
#   26980,
#   'Automatic',
#   5000,
#   'Hybrid',
#   72.4,
#   492.8,
#   411.54,
#   180): 'Corolla',
#  (2019,
#   21995,
#   'Automatic',
#   8789,
#   'Hybrid',
#   85.6,
#   401.75,
#   351.6,
#   122): 'Corolla',
#  (2019,
#   18995,
#   'Manual',
#   2193,
#   'Gasoline',
#   39.2,
#   346.95,
#   306.38,
#   116): 'Corolla',
#  (2019,
#   22498,
#   'Automatic',
#   9798,
#   'Hybrid',
#   78.5,
#   410.94,
#   359.19,
#   122): 'Corolla',
#  (2019,
#   20998,
#   'Automatic',
#   8442,
#   'Hybrid',
#   85.6,
#   383.54,
#   336.58,
#   122): 'Corolla',
#  (2019,
#   27990,
#   'Automatic',
#   3650,
#   'Hybrid',
#   72.4,
#   511.25,
#   441.97,
#   180): 'Corolla',
#  (2019,
#   22520,
#   'Automatic',
#   7666,
#   'Hybrid',
#   85.6,
#   411.34,
#   359.52,
#   122): 'Corolla',
#  (2019,
#   17440,
#   'Manual',
#   6346,
#   'Gasoline',
#   39.2,
#   318.55,
#   282.94,
#   116): 'Corolla',
#  (2019,
#   22990,
#   'Automatic',
#   9000,
#   'Hybrid',
#   78.5,
#   419.92,
#   366.6,
#   122): 'Corolla',
#  (2019,
#   25570,
#   'Automatic',
#   3196,
#   'Hybrid',
#   72.4,
#   467.05,
#   405.5,
#   180): 'Corolla',
#  (2019,
#   19998,
#   'Automatic',
#   1992,
#   'Hybrid',
#   85.6,
#   365.27,
#   321.5,
#   122): 'Corolla',
#  (2019,
#   23990,
#   'Automatic',
#   9500,
#   'Hybrid',
#   78.5,
#   438.19,
#   381.68,
#   122): 'Corolla',
#  (2019,
#   19995,
#   'Automatic',
#   12158,
#   'Hybrid',
#   85.6,
#   365.22,
#   321.46,
#   122): 'Corolla',
#  (2019,
#   24995,
#   'Automatic',
#   5500,
#   'Hybrid',
#   72.4,
#   456.55,
#   396.83,
#   180): 'Corolla',
#  (2019,
#   24995,
#   'Automatic',
#   1350,
#   'Hybrid',
#   72.4,
#   456.55,
#   396.83,
#   180): 'Corolla',
#  (2019,
#   23440,
#   'Automatic',
#   5000,
#   'Hybrid',
#   78.5,
#   428.14,
#   373.39,
#   122): 'Corolla',
#  (2019,
#   21990,
#   'Automatic',
#   9278,
#   'Hybrid',
#   85.6,
#   401.66,
#   351.53,
#   122): 'Corolla',
#  (2019,
#   20990,
#   'Automatic',
#   5000,
#   'Hybrid',
#   85.6,
#   383.39,
#   336.46,
#   122): 'Corolla',
#  (2019,
#   19990,
#   'Automatic',
#   10500,
#   'Hybrid',
#   85.6,
#   365.13,
#   321.38,
#   122): 'Corolla',
#  (2019,
#   21995,
#   'Automatic',
#   9100,
#   'Hybrid',
#   58.9,
#   401.75,
#   351.6,
#   122): 'Corolla',
#  (2019,
#   22070,
#   'Automatic',
#   9304,
#   'Hybrid',
#   78.5,
#   403.12,
#   352.74,
#   122): 'Corolla',
#  (2019,
#   22490,
#   'Automatic',
#   9500,
#   'Hybrid',
#   85.6,
#   410.79,
#   359.07,
#   122): 'Corolla',
#  (2019,
#   15990,
#   'Manual',
#   3500,
#   'Gasoline',
#   39.2,
#   292.07,
#   261.08,
#   116): 'Corolla',
#  (2019,
#   21998,
#   'Automatic',
#   9023,
#   'Hybrid',
#   72.4,
#   401.8,
#   351.65,
#   180): 'Corolla',
#  (2019,
#   22075,
#   'Automatic',
#   9684,
#   'Hybrid',
#   85.6,
#   403.21,
#   352.81,
#   122): 'Corolla',
#  (2020,
#   28990,
#   'Automatic',
#   2000,
#   'Hybrid',
#   53.3,
#   529.52,
#   440.71,
#   180): 'Corolla',
#  (2019,
#   16995,
#   'Manual',
#   6503,
#   'Gasoline',
#   39.2,
#   310.42,
#   276.23,
#   116): 'Corolla',
#  (2019,
#   18498,
#   'Manual',
#   5087,
#   'Gasoline',
#   39.2,
#   337.87,
#   298.89,
#   116): 'Corolla',
#  (2019,
#   25995,
#   'Automatic',
#   1751,
#   'Hybrid',
#   72.4,
#   474.81,
#   411.9,
#   180): 'Corolla',
#  (2019,
#   24998,
#   'Automatic',
#   6195,
#   'Hybrid',
#   72.4,
#   456.6,
#   396.87,
#   180): 'Corolla',
#  (2019,
#   23500,
#   'Automatic',
#   4720,
#   'Hybrid',
#   78.5,
#   429.24,
#   374.29,
#   122): 'Corolla',
#  (2019,
#   21750,
#   'Automatic',
#   2839,
#   'Hybrid',
#   85.6,
#   397.27,
#   347.91,
#   122): 'Corolla',
#  (2019,
#   21000,
#   'Automatic',
#   11408,
#   'Hybrid',
#   85.6,
#   383.58,
#   336.61,
#   122): 'Corolla',
#  (2019,
#   23000,
#   'Automatic',
#   6788,
#   'Hybrid',
#   85.6,
#   420.11,
#   366.75,
#   122): 'Corolla',
#  (2019,
#   25000,
#   'Automatic',
#   2430,
#   'Hybrid',
#   78.5,
#   456.64,
#   396.9,
#   122): 'Corolla',
#  (2019,
#   23000,
#   'Automatic',
#   3579,
#   'Hybrid',
#   72.4,
#   420.11,
#   366.75,
#   180): 'Corolla',
#  (2019,
#   24000,
#   'Automatic',
#   6415,
#   'Hybrid',
#   72.4,
#   438.37,
#   381.83,
#   180): 'Corolla',
#  (2019,
#   22500,
#   'Automatic',
#   9493,
#   'Hybrid',
#   78.5,
#   410.97,
#   359.22,
#   122): 'Corolla',
#  (2019,
#   22790,
#   'Automatic',
#   5830,
#   'Hybrid',
#   72.4,
#   416.27,
#   363.59,
#   180): 'Corolla',
#  (2019,
#   22790,
#   'Automatic',
#   9781,
#   'Hybrid',
#   72.4,
#   416.27,
#   363.59,
#   180): 'Corolla',
#  (2019,
#   21490,
#   'Automatic',
#   8950,
#   'Hybrid',
#   72.4,
#   392.53,
#   343.99,
#   180): 'Corolla',
#  (2019,
#   17250,
#   'Manual',
#   12000,
#   'Gasoline',
#   39.2,
#   315.08,
#   280.08,
#   116): 'Corolla',
#  (2019,
#   15998,
#   'Manual',
#   7016,
#   'Gasoline',
#   39.2,
#   292.21,
#   261.2,
#   116): 'Corolla',
#  (2019,
#   20498,
#   'Automatic',
#   13872,
#   'Hybrid',
#   72.4,
#   374.41,
#   329.04,
#   180): 'Corolla',
#  (2019,
#   15990,
#   'Manual',
#   2336,
#   'Gasoline',
#   39.2,
#   292.07,
#   261.08,
#   116): 'Corolla',
#  (2019,
#   20488,
#   'Automatic',
#   3892,
#   'Hybrid',
#   58.9,
#   374.22,
#   328.89,
#   122): 'Corolla',
#  (2019,
#   20288,
#   'Manual',
#   4886,
#   'Gasoline',
#   39.2,
#   370.57,
#   325.87,
#   116): 'Corolla',
#  (2019,
#   17995,
#   'Manual',
#   9770,
#   'Gasoline',
#   39.2,
#   328.69,
#   291.31,
#   116): 'Corolla',
#  (2019,
#   16490,
#   'Manual',
#   8599,
#   'Gasoline',
#   39.2,
#   301.2,
#   268.62,
#   116): 'Corolla',
#  (2019,
#   15990,
#   'Manual',
#   5346,
#   'Gasoline',
#   39.2,
#   292.07,
#   261.08,
#   116): 'Corolla',
#  (2019,
#   18290,
#   'Manual',
#   3250,
#   'Gasoline',
#   39.2,
#   334.08,
#   295.75,
#   116): 'Corolla',
#  (2019,
#   19998,
#   'Manual',
#   4290,
#   'Gasoline',
#   39.2,
#   365.27,
#   321.5,
#   116): 'Corolla',
#  (2019,
#   23888,
#   'Automatic',
#   3497,
#   'Hybrid',
#   72.4,
#   436.33,
#   380.14,
#   180): 'Corolla',
#  (2019,
#   15990,
#   'Manual',
#   6449,
#   'Gasoline',
#   39.2,
#   292.07,
#   261.08,
#   116): 'Corolla',
#  (2020,
#   27495,
#   'Automatic',
#   998,
#   'Hybrid',
#   53.3,
#   502.21,
#   419.01,
#   180): 'Corolla',
#  (2019,
#   23448,
#   'Automatic',
#   3988,
#   'Hybrid',
#   72.4,
#   428.29,
#   373.51,
#   180): 'Corolla',
#  (2019,
#   22990,
#   'Automatic',
#   5268,
#   'Hybrid',
#   72.4,
#   419.92,
#   366.6,
#   180): 'Corolla',
#  (2019,
#   18295,
#   'Manual',
#   1110,
#   'Gasoline',
#   39.2,
#   334.17,
#   295.83,
#   116): 'Corolla',
#  (2019,
#   18995,
#   'Manual',
#   1436,
#   'Gasoline',
#   39.2,
#   346.95,
#   306.38,
#   116): 'Corolla',
#  (2019,
#   21490,
#   'Automatic',
#   9296,
#   'Hybrid',
#   58.9,
#   392.53,
#   343.99,
#   122): 'Corolla',
#  (2019,
#   22790,
#   'Automatic',
#   8322,
#   'Hybrid',
#   72.4,
#   416.27,
#   363.59,
#   180): 'Corolla',
#  (2019,
#   17490,
#   'Manual',
#   9000,
#   'Gasoline',
#   39.2,
#   319.46,
#   283.7,
#   116): 'Corolla',
#  (2019,
#   24388,
#   'Automatic',
#   8000,
#   'Hybrid',
#   72.4,
#   445.46,
#   387.68,
#   180): 'Corolla',
#  (2020,
#   25988,
#   'Automatic',
#   10000,
#   'Hybrid',
#   53.3,
#   474.68,
#   397.15,
#   180): 'Corolla',
#  (2019,
#   16490,
#   'Manual',
#   8328,
#   'Gasoline',
#   39.2,
#   301.2,
#   268.62,
#   116): 'Corolla',
#  (2019,
#   21790,
#   'Automatic',
#   10836,
#   'Hybrid',
#   78.5,
#   398.0,
#   348.51,
#   122): 'Corolla',
#  (2019,
#   16490,
#   'Manual',
#   4890,
#   'Gasoline',
#   39.2,
#   301.2,
#   268.62,
#   116): 'Corolla',
#  (2019,
#   24790,
#   'Automatic',
#   5651,
#   'Hybrid',
#   72.4,
#   452.8,
#   393.74,
#   180): 'Corolla',
#  (2019,
#   21490,
#   'Automatic',
#   9735,
#   'Hybrid',
#   78.5,
#   392.53,
#   343.99,
#   122): 'Corolla',
#  (2019,
#   18495,
#   'Manual',
#   8514,
#   'Gasoline',
#   39.2,
#   337.82,
#   298.84,
#   116): 'Corolla',
#  (2019,
#   18495,
#   'Manual',
#   4774,
#   'Gasoline',
#   39.2,
#   337.82,
#   298.84,
#   116): 'Corolla',
#  (2019,
#   24995,
#   'Automatic',
#   7500,
#   'Hybrid',
#   58.9,
#   456.55,
#   396.83,
#   122): 'Corolla',
#  (2019,
#   16995,
#   'Manual',
#   3000,
#   'Gasoline',
#   39.2,
#   310.42,
#   276.23,
#   116): 'Corolla',
#  (2019,
#   22790,
#   'Automatic',
#   12501,
#   'Hybrid',
#   72.4,
#   416.27,
#   363.59,
#   180): 'Corolla',
#  (2020,
#   25990,
#   'Automatic',
#   6124,
#   'Hybrid',
#   53.3,
#   474.72,
#   397.18,
#   180): 'Corolla',
#  (2019,
#   21490,
#   'Automatic',
#   10124,
#   'Hybrid',
#   85.6,
#   392.53,
#   343.99,
#   122): 'Corolla',
#  (2019,
#   21490,
#   'Automatic',
#   9107,
#   'Hybrid',
#   72.4,
#   392.53,
#   343.99,
#   180): 'Corolla',
#  (2019,
#   23698,
#   'Automatic',
#   2535,
#   'Hybrid',
#   72.4,
#   432.86,
#   377.28,
#   180): 'Corolla',
#  (2020,
#   22990,
#   'Automatic',
#   2797,
#   'Hybrid',
#   62.8,
#   419.92,
#   353.64,
#   122): 'Corolla',
#  (2020,
#   26490,
#   'Automatic',
#   1879,
#   'Hybrid',
#   53.3,
#   483.85,
#   404.43,
#   180): 'Corolla',
#  (2020,
#   25490,
#   'Automatic',
#   1697,
#   'Hybrid',
#   56.5,
#   465.59,
#   389.92,
#   122): 'Corolla',
#  (2019,
#   22990,
#   'Automatic',
#   13410,
#   'Hybrid',
#   72.4,
#   419.92,
#   366.6,
#   180): 'Corolla',
#  (2019,
#   19990,
#   'Manual',
#   4332,
#   'Gasoline',
#   39.2,
#   365.13,
#   321.38,
#   116): 'Corolla',
#  (2019,
#   20990,
#   'Manual',
#   8503,
#   'Gasoline',
#   39.2,
#   383.39,
#   336.46,
#   116): 'Corolla',
#  (2019,
#   17890,
#   'Manual',
#   3695,
#   'Gasoline',
#   39.2,
#   326.77,
#   289.73,
#   116): 'Corolla',
#  (2019,
#   18995,
#   'Manual',
#   2579,
#   'Gasoline',
#   39.2,
#   346.95,
#   306.38,
#   116): 'Corolla',
#  (2019,
#   17990,
#   'Manual',
#   6057,
#   'Gasoline',
#   39.2,
#   328.6,
#   291.23,
#   116): 'Corolla',
#  (2019,
#   18690,
#   'Manual',
#   2907,
#   'Gasoline',
#   39.2,
#   341.38,
#   301.78,
#   116): 'Corolla',
#  (2019,
#   16990,
#   'Manual',
#   7134,
#   'Gasoline',
#   39.2,
#   310.33,
#   276.16,
#   116): 'Corolla',
#  (2019, 16990, 'Manual', 25, 'Gasoline', 39.2, 310.33, 276.16, 116): 'Corolla',
#  (2019,
#   22727,
#   'Automatic',
#   4451,
#   'Hybrid',
#   72.4,
#   415.12,
#   362.64,
#   180): 'Corolla',
#  (2019,
#   20995,
#   'Automatic',
#   5668,
#   'Hybrid',
#   72.4,
#   383.48,
#   336.53,
#   180): 'Corolla',
#  (2019,
#   20995,
#   'Automatic',
#   5250,
#   'Hybrid',
#   85.6,
#   383.48,
#   336.53,
#   122): 'Corolla',
#  (2019,
#   22290,
#   'Automatic',
#   4633,
#   'Hybrid',
#   78.5,
#   407.14,
#   356.05,
#   122): 'Corolla',
#  (2019,
#   16490,
#   'Manual',
#   9625,
#   'Gasoline',
#   39.2,
#   301.2,
#   268.62,
#   116): 'Corolla',
#  (2019,
#   19790,
#   'Automatic',
#   5804,
#   'Hybrid',
#   85.6,
#   361.47,
#   318.37,
#   122): 'Corolla',
#  (2019,
#   15790,
#   'Manual',
#   10000,
#   'Gasoline',
#   39.2,
#   288.41,
#   258.07,
#   116): 'Corolla',
#  (2019,
#   17480,
#   'Manual',
#   9999,
#   'Gasoline',
#   39.2,
#   319.28,
#   283.54,
#   116): 'Corolla',
#  (2020,
#   24980,
#   'Automatic',
#   5000,
#   'Hybrid',
#   57.7,
#   456.27,
#   382.52,
#   122): 'Corolla',
#  (2019,
#   18990,
#   'Manual',
#   3860,
#   'Gasoline',
#   39.2,
#   346.86,
#   306.31,
#   116): 'Corolla',
#  (2019,
#   21495,
#   'Automatic',
#   9004,
#   'Hybrid',
#   85.6,
#   392.62,
#   344.07,
#   122): 'Corolla',
#  (2019,
#   17960,
#   'Manual',
#   4500,
#   'Gasoline',
#   39.2,
#   328.05,
#   290.78,
#   116): 'Corolla',
#  (2019,
#   23995,
#   'Automatic',
#   5784,
#   'Hybrid',
#   72.4,
#   438.28,
#   381.75,
#   180): 'Corolla',
#  (2019,
#   17995,
#   'Manual',
#   6551,
#   'Gasoline',
#   39.2,
#   328.69,
#   291.31,
#   116): 'Corolla',
#  (2019,
#   24795,
#   'Automatic',
#   6770,
#   'Hybrid',
#   72.4,
#   452.89,
#   393.81,
#   180): 'Corolla',
#  (2019,
#   18995,
#   'Manual',
#   500,
#   'Gasoline',
#   39.2,
#   346.95,
#   306.38,
#   116): 'Corolla',
#  (2019,
#   19995,
#   'Manual',
#   500,
#   'Gasoline',
#   39.2,
#   365.22,
#   321.46,
#   116): 'Corolla',
#  (2019,
#   22595,
#   'Automatic',
#   10500,
#   'Hybrid',
#   72.4,
#   412.71,
#   360.65,
#   180): 'Corolla',
#  (2019,
#   25595,
#   'Automatic',
#   1215,
#   'Hybrid',
#   78.5,
#   467.51,
#   405.87,
#   122): 'Corolla',
#  (2019,
#   23445,
#   'Automatic',
#   5558,
#   'Hybrid',
#   78.5,
#   428.23,
#   373.46,
#   122): 'Corolla',
#  (2019,
#   23395,
#   'Automatic',
#   6125,
#   'Hybrid',
#   78.5,
#   427.32,
#   372.71,
#   122): 'Corolla',
#  (2019,
#   23445,
#   'Automatic',
#   2620,
#   'Hybrid',
#   78.5,
#   428.23,
#   373.46,
#   122): 'Corolla',
#  (2019,
#   24998,
#   'Automatic',
#   2474,
#   'Hybrid',
#   72.4,
#   456.6,
#   396.87,
#   180): 'Corolla',
#  (2019,
#   23498,
#   'Automatic',
#   6513,
#   'Hybrid',
#   78.5,
#   429.2,
#   374.26,
#   122): 'Corolla',
#  (2019,
#   23995,
#   'Automatic',
#   6989,
#   'Hybrid',
#   72.4,
#   438.28,
#   381.75,
#   180): 'Corolla',
#  (2019,
#   22995,
#   'Automatic',
#   11000,
#   'Hybrid',
#   72.4,
#   420.01,
#   366.68,
#   180): 'Corolla',
#  (2019,
#   22995,
#   'Automatic',
#   3754,
#   'Hybrid',
#   78.5,
#   420.01,
#   366.68,
#   122): 'Corolla',
#  (2020,
#   28815,
#   'Automatic',
#   987,
#   'Hybrid',
#   53.3,
#   526.32,
#   438.17,
#   180): 'Corolla',
#  (2019,
#   19995,
#   'Automatic',
#   11293,
#   'Hybrid',
#   85.6,
#   365.22,
#   321.46,
#   122): 'Corolla',
#  (2019,
#   19995,
#   'Automatic',
#   5674,
#   'Hybrid',
#   85.6,
#   365.22,
#   321.46,
#   122): 'Corolla',
#  (2019,
#   23995,
#   'Automatic',
#   9250,
#   'Hybrid',
#   72.4,
#   438.28,
#   381.75,
#   180): 'Corolla',
#  (2019,
#   23495,
#   'Manual',
#   5600,
#   'Gasoline',
#   39.2,
#   429.15,
#   374.22,
#   116): 'Corolla',
#  (2020,
#   27995,
#   'Automatic',
#   2500,
#   'Hybrid',
#   53.3,
#   511.34,
#   426.27,
#   180): 'Corolla',
#  (2019,
#   21000,
#   'Automatic',
#   11449,
#   'Hybrid',
#   78.5,
#   383.58,
#   336.61,
#   122): 'Corolla',
#  (2020,
#   28000,
#   'Automatic',
#   10,
#   'Hybrid',
#   56.5,
#   511.43,
#   426.34,
#   122): 'Corolla',
#  (2019,
#   17999,
#   'Manual',
#   3510,
#   'Gasoline',
#   39.2,
#   328.76,
#   291.37,
#   116): 'Corolla',
#  (2019,
#   20497,
#   'Automatic',
#   4412,
#   'Hybrid',
#   78.5,
#   374.39,
#   329.02,
#   122): 'Corolla',
#  (2019,
#   23500,
#   'Automatic',
#   10016,
#   'Hybrid',
#   78.5,
#   429.24,
#   374.29,
#   122): 'Corolla',
#  (2019,
#   21665,
#   'Automatic',
#   11051,
#   'Hybrid',
#   85.6,
#   395.72,
#   346.63,
#   122): 'Corolla',
#  (2019,
#   21280,
#   'Manual',
#   5102,
#   'Gasoline',
#   39.2,
#   388.69,
#   340.83,
#   116): 'Corolla',
#  (2019,
#   24960,
#   'Automatic',
#   2535,
#   'Hybrid',
#   72.4,
#   455.91,
#   396.3,
#   180): 'Corolla',
#  (2019,
#   19540,
#   'Manual',
#   8970,
#   'Gasoline',
#   39.2,
#   356.91,
#   314.6,
#   116): 'Corolla',
#  (2019,
#   20110,
#   'Automatic',
#   5922,
#   'Hybrid',
#   85.6,
#   367.32,
#   323.19,
#   122): 'Corolla',
#  (2019,
#   23060,
#   'Automatic',
#   15631,
#   'Hybrid',
#   72.4,
#   421.2,
#   367.66,
#   180): 'Corolla',
#  (2020,
#   26991,
#   'Automatic',
#   3636,
#   'Hybrid',
#   53.3,
#   493.0,
#   411.7,
#   180): 'Corolla',
#  (2019,
#   22900,
#   'Automatic',
#   5910,
#   'Hybrid',
#   85.6,
#   418.28,
#   365.25,
#   122): 'Corolla',
#  (2019,
#   24025,
#   'Automatic',
#   8812,
#   'Hybrid',
#   78.5,
#   438.83,
#   382.21,
#   122): 'Corolla',
#  (2019,
#   26495,
#   'Automatic',
#   1000,
#   'Hybrid',
#   72.4,
#   483.94,
#   419.44,
#   180): 'Corolla',
#  (2019,
#   27795,
#   'Automatic',
#   1000,
#   'Hybrid',
#   72.4,
#   507.69,
#   439.04,
#   180): 'Corolla',
#  (2019,
#   22999,
#   'Automatic',
#   4113,
#   'Hybrid',
#   85.6,
#   420.09,
#   366.74,
#   122): 'Corolla',
#  (2019,
#   21999,
#   'Automatic',
#   8171,
#   'Hybrid',
#   78.5,
#   401.82,
#   351.67,
#   122): 'Corolla',
#  (2019,
#   19990,
#   'Manual',
#   3422,
#   'Gasoline',
#   39.2,
#   365.13,
#   321.38,
#   116): 'Corolla',
#  (2019,
#   19900,
#   'Manual',
#   6522,
#   'Gasoline',
#   39.2,
#   363.48,
#   320.02,
#   116): 'Corolla',
#  (2019,
#   22000,
#   'Automatic',
#   11478,
#   'Hybrid',
#   78.5,
#   401.84,
#   351.68,
#   122): 'Corolla',
#  (2019,
#   19290,
#   'Manual',
#   10011,
#   'Gasoline',
#   39.2,
#   352.34,
#   310.83,
#   116): 'Corolla',
#  (2019,
#   19995,
#   'Manual',
#   7777,
#   'Gasoline',
#   39.2,
#   365.22,
#   321.46,
#   116): 'Corolla',
#  (2019,
#   23888,
#   'Automatic',
#   14417,
#   'Hybrid',
#   72.4,
#   436.33,
#   380.14,
#   180): 'Corolla',
#  (2019,
#   22495,
#   'Automatic',
#   2034,
#   'Hybrid',
#   78.5,
#   410.88,
#   359.14,
#   122): 'Corolla',
#  (2020,
#   28495,
#   'Automatic',
#   2141,
#   'Hybrid',
#   56.5,
#   520.48,
#   433.52,
#   122): 'Corolla',
#  (2019,
#   25195,
#   'Automatic',
#   3998,
#   'Hybrid',
#   72.4,
#   460.2,
#   399.84,
#   180): 'Corolla',
#  (2019,
#   21495,
#   'Automatic',
#   10420,
#   'Hybrid',
#   85.6,
#   392.62,
#   344.07,
#   122): 'Corolla',
#  (2019,
#   21790,
#   'Automatic',
#   10120,
#   'Hybrid',
#   78.5,
#   398.0,
#   348.51,
#   122): 'Corolla',
#  (2020,
#   24995,
#   'Automatic',
#   3989,
#   'Hybrid',
#   57.7,
#   456.55,
#   382.74,
#   122): 'Corolla',
#  (2020,
#   22995,
#   'Automatic',
#   636,
#   'Hybrid',
#   62.8,
#   420.01,
#   353.72,
#   122): 'Corolla',
#  (2019,
#   26995,
#   'Automatic',
#   3000,
#   'Hybrid',
#   72.4,
#   493.08,
#   426.98,
#   180): 'Corolla',
#  (2019,
#   21995,
#   'Automatic',
#   9333,
#   'Hybrid',
#   78.5,
#   401.75,
#   351.6,
#   122): 'Corolla',
#  (2019,
#   17495,
#   'Manual',
#   999,
#   'Gasoline',
#   39.2,
#   319.55,
#   283.77,
#   116): 'Corolla',
#  (2019,
#   22050,
#   'Automatic',
#   12000,
#   'Hybrid',
#   72.4,
#   402.75,
#   352.43,
#   180): 'Corolla',
#  (2020,
#   28795,
#   'Automatic',
#   1544,
#   'Hybrid',
#   53.3,
#   525.95,
#   437.88,
#   180): 'Corolla',
#  (2020,
#   20692,
#   'Manual',
#   7345,
#   'Gasoline',
#   39.2,
#   377.95,
#   320.3,
#   116): 'Corolla',
#  (2019,
#   21495,
#   'Automatic',
#   20657,
#   'Hybrid',
#   85.6,
#   392.62,
#   344.07,
#   122): 'Corolla',
#  (2019,
#   22514,
#   'Automatic',
#   8309,
#   'Hybrid',
#   78.5,
#   411.23,
#   359.43,
#   122): 'Corolla',
#  (2020,
#   29450,
#   'Automatic',
#   943,
#   'Hybrid',
#   53.3,
#   537.92,
#   447.38,
#   180): 'Corolla',
#  (2020,
#   26950,
#   'Automatic',
#   3168,
#   'Hybrid',
#   53.3,
#   492.25,
#   411.11,
#   180): 'Corolla',
#  (2020,
#   24995,
#   'Automatic',
#   2136,
#   'Hybrid',
#   56.5,
#   456.55,
#   382.74,
#   122): 'Corolla',
#  (2019,
#   23000,
#   'Automatic',
#   6158,
#   'Hybrid',
#   72.4,
#   420.11,
#   366.75,
#   180): 'Corolla',
#  (2019,
#   20689,
#   'Automatic',
#   7963,
#   'Hybrid',
#   85.6,
#   377.89,
#   331.92,
#   122): 'Corolla',
#  (2019,
#   19219,
#   'Manual',
#   384,
#   'Gasoline',
#   39.2,
#   351.04,
#   309.76,
#   116): 'Corolla',
#  (2019,
#   21991,
#   'Automatic',
#   5000,
#   'Hybrid',
#   78.5,
#   401.68,
#   351.54,
#   122): 'Corolla',
#  (2019,
#   22980,
#   'Automatic',
#   3459,
#   'Hybrid',
#   72.4,
#   419.74,
#   366.45,
#   180): 'Corolla',
#  (2019,
#   15291,
#   'Manual',
#   7317,
#   'Gasoline',
#   39.2,
#   279.3,
#   250.55,
#   116): 'Corolla',
#  (2019,
#   22780,
#   'Automatic',
#   9980,
#   'Hybrid',
#   72.4,
#   416.09,
#   363.44,
#   180): 'Corolla',
#  (2020,
#   19495,
#   'Manual',
#   4568,
#   'Gasoline',
#   39.2,
#   356.09,
#   302.93,
#   116): 'Corolla',
#  (2019,
#   18991,
#   'Automatic',
#   7000,
#   'Hybrid',
#   85.6,
#   346.88,
#   306.32,
#   122): 'Corolla',
#  (2019,
#   19291,
#   'Automatic',
#   13998,
#   'Hybrid',
#   85.6,
#   352.36,
#   310.84,
#   122): 'Corolla',
#  (2019,
#   23505,
#   'Automatic',
#   9264,
#   'Hybrid',
#   78.5,
#   429.33,
#   374.37,
#   122): 'Corolla',
#  (2019,
#   17865,
#   'Manual',
#   17197,
#   'Gasoline',
#   39.2,
#   326.31,
#   289.35,
#   116): 'Corolla',
#  (2019,
#   20499,
#   'Automatic',
#   4942,
#   'Hybrid',
#   85.6,
#   374.42,
#   329.05,
#   122): 'Corolla',
#  (2020,
#   27893,
#   'Automatic',
#   3390,
#   'Hybrid',
#   72.4,
#   509.48,
#   424.79,
#   180): 'Corolla',
#  (2019,
#   22226,
#   'Automatic',
#   9264,
#   'Hybrid',
#   78.5,
#   405.97,
#   355.09,
#   122): 'Corolla',
#  (2019,
#   16821,
#   'Manual',
#   6329,
#   'Gasoline',
#   39.2,
#   307.24,
#   273.61,
#   116): 'Corolla',
#  (2020,
#   25998,
#   'Automatic',
#   5000,
#   'Hybrid',
#   53.3,
#   474.87,
#   397.29,
#   180): 'Corolla',
#  (2003, 1495, 'Manual', 89000, 'Gasoline', 39.2, 27.31, 42.58, 132): 'Corolla',
#  (2019,
#   20995,
#   'Automatic',
#   6834,
#   'Hybrid',
#   72.4,
#   383.48,
#   336.53,
#   180): 'Corolla',
#  (2019,
#   17989,
#   'Manual',
#   151,
#   'Gasoline',
#   39.2,
#   328.58,
#   291.22,
#   116): 'Corolla',
#  (2019,
#   26999,
#   'Automatic',
#   6500,
#   'Hybrid',
#   72.4,
#   493.15,
#   427.04,
#   180): 'Corolla',
#  (2019,
#   16495,
#   'Manual',
#   5517,
#   'Gasoline',
#   39.2,
#   301.29,
#   268.7,
#   116): 'Corolla',
#  (2019,
#   17995,
#   'Manual',
#   3792,
#   'Gasoline',
#   39.2,
#   328.69,
#   291.31,
#   116): 'Corolla',
#  (2019,
#   16495,
#   'Manual',
#   5139,
#   'Gasoline',
#   39.2,
#   301.29,
#   268.7,
#   116): 'Corolla',
#  (2019,
#   23995,
#   'Automatic',
#   42,
#   'Hybrid',
#   57.7,
#   438.28,
#   381.75,
#   122): 'Corolla',
#  (2020,
#   25995,
#   'Automatic',
#   100,
#   'Hybrid',
#   53.3,
#   474.81,
#   397.25,
#   180): 'Corolla',
#  (2019,
#   22250,
#   'Automatic',
#   10932,
#   'Hybrid',
#   78.5,
#   406.41,
#   355.45,
#   122): 'Corolla',
#  (2019,
#   19995,
#   'Automatic',
#   14198,
#   'Hybrid',
#   85.6,
#   365.22,
#   321.46,
#   122): 'Corolla',
#  (2019,
#   22485,
#   'Automatic',
#   9111,
#   'Hybrid',
#   78.5,
#   410.7,
#   358.99,
#   122): 'Corolla',
#  (2019,
#   20985,
#   'Automatic',
#   5372,
#   'Hybrid',
#   85.6,
#   383.3,
#   336.38,
#   122): 'Corolla',
#  (2019,
#   21999,
#   'Automatic',
#   17095,
#   'Hybrid',
#   72.4,
#   401.82,
#   351.67,
#   180): 'Corolla',
#  (2019, 17999, 'Manual', 20, 'Gasoline', 39.2, 328.76, 291.37, 116): 'Corolla',
#  (2019, 17499, 'Manual', 20, 'Gasoline', 39.2, 319.63, 283.83, 116): 'Corolla',
#  (2019,
#   16299,
#   'Manual',
#   18020,
#   'Gasoline',
#   39.2,
#   297.71,
#   265.74,
#   116): 'Corolla',
#  (2019,
#   21450,
#   'Automatic',
#   9244,
#   'Hybrid',
#   85.6,
#   391.79,
#   343.39,
#   122): 'Corolla',
#  (2019,
#   20499,
#   'Automatic',
#   10436,
#   'Hybrid',
#   78.5,
#   374.42,
#   329.05,
#   122): 'Corolla',
#  (2019, 16491, 'Manual', 15, 'Gasoline', 39.2, 301.22, 268.64, 116): 'Corolla',
#  (2019,
#   21450,
#   'Automatic',
#   7899,
#   'Hybrid',
#   85.6,
#   391.79,
#   343.39,
#   122): 'Corolla',
#  (2019,
#   21450,
#   'Automatic',
#   8908,
#   'Hybrid',
#   78.5,
#   391.79,
#   343.39,
#   122): 'Corolla',
#  (2019,
#   21995,
#   'Automatic',
#   4800,
#   'Hybrid',
#   85.6,
#   401.75,
#   351.6,
#   122): 'Corolla',
#  (2019,
#   22691,
#   'Automatic',
#   3698,
#   'Hybrid',
#   72.4,
#   414.46,
#   362.1,
#   180): 'Corolla',
#  (2019, 15991, 'Manual', 10, 'Gasoline', 39.2, 292.08, 261.1, 116): 'Corolla',
#  (2019,
#   23490,
#   'Automatic',
#   8239,
#   'Hybrid',
#   78.5,
#   429.06,
#   374.14,
#   122): 'Corolla',
#  (2019,
#   25495,
#   'Automatic',
#   9317,
#   'Hybrid',
#   85.6,
#   465.68,
#   404.36,
#   122): 'Corolla',
#  (2001,
#   899,
#   'Automatic',
#   76000,
#   'Gasoline',
#   35.3,
#   16.42,
#   33.6,
#   132): 'Corolla',
#  (2019, 17790, 'Manual', 15, 'Gasoline', 39.2, 324.94, 288.22, 116): 'Corolla',
#  (2019, 17990, 'Manual', 10, 'Gasoline', 39.2, 328.6, 291.23, 116): 'Corolla',
#  (2019, 16990, 'Manual', 10, 'Gasoline', 39.2, 310.33, 276.16, 116): 'Corolla',
#  (2019,
#   19795,
#   'Automatic',
#   7841,
#   'Hybrid',
#   78.5,
#   361.57,
#   318.44,
#   122): 'Corolla',
#  (2019,
#   23395,
#   'Automatic',
#   10513,
#   'Hybrid',
#   85.6,
#   427.32,
#   372.71,
#   122): 'Corolla',
#  (2019,
#   18700,
#   'Manual',
#   6597,
#   'Gasoline',
#   39.2,
#   341.56,
#   301.94,
#   116): 'Corolla',
#  (2019,
#   22700,
#   'Automatic',
#   6289,
#   'Hybrid',
#   78.5,
#   414.63,
#   362.23,
#   122): 'Corolla',
#  (2019, 16790, 'Manual', 97, 'Gasoline', 39.2, 306.68, 273.14, 116): 'Corolla',
#  (2019,
#   23700,
#   'Automatic',
#   3628,
#   'Hybrid',
#   72.4,
#   432.89,
#   377.31,
#   180): 'Corolla',
#  (2020,
#   26700,
#   'Automatic',
#   3675,
#   'Hybrid',
#   53.3,
#   487.69,
#   407.48,
#   180): 'Corolla',
#  (2019,
#   23650,
#   'Automatic',
#   8087,
#   'Hybrid',
#   72.4,
#   431.98,
#   376.55,
#   180): 'Corolla',
#  (2019,
#   21990,
#   'Automatic',
#   12000,
#   'Hybrid',
#   78.5,
#   401.66,
#   351.53,
#   122): 'Corolla',
#  (2020,
#   19790,
#   'Manual',
#   3000,
#   'Gasoline',
#   39.2,
#   361.47,
#   307.21,
#   116): 'Corolla',
#  (2019,
#   20450,
#   'Automatic',
#   8000,
#   'Hybrid',
#   85.6,
#   373.53,
#   328.32,
#   122): 'Corolla',
#  (2019,
#   16200,
#   'Manual',
#   3837,
#   'Gasoline',
#   39.2,
#   295.9,
#   264.25,
#   116): 'Corolla',
#  (2019,
#   21491,
#   'Automatic',
#   3993,
#   'Hybrid',
#   85.6,
#   392.54,
#   344.01,
#   122): 'Corolla',
#  (2019,
#   21850,
#   'Automatic',
#   9300,
#   'Hybrid',
#   58.9,
#   399.1,
#   349.42,
#   122): 'Corolla',
#  (2020,
#   23550,
#   'Automatic',
#   3000,
#   'Hybrid',
#   58.9,
#   430.15,
#   361.77,
#   122): 'Corolla',
#  (2019,
#   21991,
#   'Automatic',
#   13000,
#   'Hybrid',
#   78.5,
#   401.68,
#   351.54,
#   122): 'Corolla',
#  (2019,
#   22850,
#   'Automatic',
#   9000,
#   'Hybrid',
#   78.5,
#   417.37,
#   364.49,
#   122): 'Corolla',
#  (2019,
#   19990,
#   'Automatic',
#   9968,
#   'Hybrid',
#   85.6,
#   365.13,
#   321.38,
#   122): 'Corolla',
#  (2019,
#   19990,
#   'Automatic',
#   10175,
#   'Hybrid',
#   85.6,
#   365.13,
#   321.38,
#   122): 'Corolla',
#  (2019,
#   25650,
#   'Automatic',
#   4000,
#   'Hybrid',
#   72.4,
#   468.51,
#   406.7,
#   180): 'Corolla',
#  (2019,
#   21350,
#   'Automatic',
#   15481,
#   'Hybrid',
#   78.5,
#   389.97,
#   341.88,
#   122): 'Corolla',
#  (2019,
#   22990,
#   'Automatic',
#   7000,
#   'Hybrid',
#   78.5,
#   419.92,
#   366.6,
#   122): 'Corolla',
#  (2019,
#   22990,
#   'Automatic',
#   6000,
#   'Hybrid',
#   78.5,
#   419.92,
#   366.6,
#   122): 'Corolla',
#  (2019,
#   23650,
#   'Automatic',
#   7000,
#   'Hybrid',
#   85.6,
#   431.98,
#   376.55,
#   122): 'Corolla',
#  (2019,
#   21990,
#   'Automatic',
#   10055,
#   'Hybrid',
#   78.5,
#   401.66,
#   351.53,
#   122): 'Corolla',
#  (2020,
#   18990,
#   'Manual',
#   3000,
#   'Gasoline',
#   39.2,
#   346.86,
#   295.6,
#   116): 'Corolla',
#  (2019,
#   21500,
#   'Automatic',
#   6610,
#   'Hybrid',
#   85.6,
#   392.71,
#   344.14,
#   122): 'Corolla',
#  (2019,
#   21690,
#   'Automatic',
#   9823,
#   'Hybrid',
#   78.5,
#   396.18,
#   347.01,
#   122): 'Corolla',
#  (2019,
#   22750,
#   'Automatic',
#   9000,
#   'Hybrid',
#   72.4,
#   415.54,
#   362.99,
#   180): 'Corolla',
#  (2019,
#   22250,
#   'Automatic',
#   8563,
#   'Hybrid',
#   78.5,
#   406.41,
#   355.45,
#   122): 'Corolla',
#  (2019,
#   24495,
#   'Automatic',
#   2165,
#   'Hybrid',
#   72.4,
#   447.41,
#   389.29,
#   180): 'Corolla',
#  (2019,
#   24295,
#   'Automatic',
#   6568,
#   'Hybrid',
#   72.4,
#   443.76,
#   386.28,
#   180): 'Corolla',
#  (2019,
#   22000,
#   'Automatic',
#   7575,
#   'Hybrid',
#   78.5,
#   401.84,
#   351.68,
#   122): 'Corolla',
#  (2019,
#   16500,
#   'Manual',
#   6170,
#   'Gasoline',
#   39.2,
#   301.38,
#   268.77,
#   116): 'Corolla',
#  (2019,
#   23500,
#   'Automatic',
#   6033,
#   'Hybrid',
#   78.5,
#   429.24,
#   374.29,
#   122): 'Corolla',
#  (2005, 3495, 'Manual', 77500, 'Gasoline', 40.4, 63.84, 72.73, 132): 'Corolla',
#  (2019,
#   23250,
#   'Automatic',
#   3568,
#   'Hybrid',
#   72.4,
#   424.67,
#   370.52,
#   180): 'Corolla',
#  (2019,
#   21494,
#   'Automatic',
#   7792,
#   'Hybrid',
#   78.5,
#   392.6,
#   344.05,
#   122): 'Corolla',
#  (2019,
#   21249,
#   'Automatic',
#   10353,
#   'Hybrid',
#   85.6,
#   388.12,
#   340.36,
#   122): 'Corolla',
#  (2019,
#   21250,
#   'Automatic',
#   7125,
#   'Hybrid',
#   85.6,
#   388.14,
#   340.37,
#   122): 'Corolla',
#  (2019,
#   21995,
#   'Automatic',
#   8661,
#   'Hybrid',
#   78.5,
#   401.75,
#   351.6,
#   122): 'Corolla',
#  (2019,
#   22995,
#   'Automatic',
#   4319,
#   'Hybrid',
#   85.6,
#   420.01,
#   366.68,
#   122): 'Corolla',
#  (2017, 16500, 'Manual', 25271, 'Diesel', 60.1, 301.38, 268.77, 150): 'RAV4',
#  (2016, 15995, 'Manual', 11291, 'Diesel', 60.1, 292.16, 261.16, 150): 'RAV4',
#  (2015, 13500, 'Manual', 45757, 'Diesel', 57.6, 246.58, 223.55, 150): 'RAV4',
#  (2015, 13698, 'Automatic', 43830, 'Diesel', 42.2, 250.2, 226.53, 177): 'RAV4',
#  (2016, 14998, 'Manual', 40054, 'Diesel', 60.1, 273.95, 246.13, 150): 'RAV4',
#  (2013,
#   10998,
#   'Automatic',
#   45322,
#   'Diesel',
#   42.2,
#   200.88,
#   185.83,
#   177): 'RAV4',
#  (2016, 13498, 'Manual', 32061, 'Diesel', 60.1, 246.55, 223.52, 150): 'RAV4',
#  (2017,
#   17500,
#   'Automatic',
#   26528,
#   'Gasoline',
#   43.5,
#   319.65,
#   283.85,
#   150): 'RAV4',
#  (2017,
#   16498,
#   'Automatic',
#   37539,
#   'Gasoline',
#   43.5,
#   301.34,
#   268.74,
#   150): 'RAV4',
#  (2014, 9698, 'Manual', 80049, 'Diesel', 53.0, 177.14, 166.24, 150): 'RAV4',
#  (2016, 14817, 'Manual', 35286, 'Diesel', 60.1, 270.64, 243.4, 150): 'RAV4',
#  (2019, 29399, 'Automatic', 9650, 'Hybrid', 51.1, 536.99, 463.21, 219): 'RAV4',
#  (2019, 32995, 'Automatic', 7017, 'Hybrid', 49.6, 602.67, 517.42, 219): 'RAV4',
#  (2019, 29995, 'Automatic', 20124, 'Hybrid', 51.1, 547.87, 472.2, 219): 'RAV4',
#  (2015, 11995, 'Manual', 49150, 'Diesel', 57.6, 219.09, 200.86, 150): 'RAV4',
#  (2016, 13995, 'Manual', 71046, 'Diesel', 60.1, 255.63, 231.01, 150): 'RAV4',
#  (2014, 12995, 'Manual', 69401, 'Diesel', 57.6, 237.36, 215.94, 150): 'RAV4',
#  (2016, 14495, 'Manual', 49097, 'Diesel', 60.1, 264.76, 238.55, 150): 'RAV4',
#  (2016, 14695, 'Manual', 39591, 'Diesel', 60.1, 268.41, 241.56, 150): 'RAV4',
#  (2019, 29498, 'Automatic', 9727, 'Hybrid', 49.6, 538.8, 464.71, 219): 'RAV4',
#  (2019, 31498, 'Automatic', 9258, 'Hybrid', 49.6, 575.33, 494.86, 219): 'RAV4',
#  (2014,
#   11498,
#   'Automatic',
#   47545,
#   'Diesel',
#   42.2,
#   210.02,
#   193.37,
#   177): 'RAV4',
#  (2014, 10998, 'Manual', 50709, 'Diesel', 53.0, 200.88, 185.83, 150): 'RAV4',
#  (2017,
#   20498,
#   'Automatic',
#   10957,
#   'Gasoline',
#   43.5,
#   374.41,
#   329.04,
#   150): 'RAV4',
#  (2013, 10498, 'Manual', 54057, 'Diesel', 49.6, 191.75, 178.3, 177): 'RAV4',
#  (2015, 9998, 'Manual', 60998, 'Diesel', 57.6, 182.62, 170.76, 150): 'RAV4',
#  (2015, 12998, 'Manual', 41486, 'Diesel', 53.0, 237.41, 215.98, 150): 'RAV4',
#  (2017, 13998, 'Manual', 48713, 'Diesel', 60.1, 255.68, 231.06, 150): 'RAV4',
#  (2017, 14698, 'Manual', 50039, 'Diesel', 60.1, 268.47, 241.61, 150): 'RAV4',
#  (2019,
#   28998,
#   'Automatic',
#   10910,
#   'Hybrid',
#   51.1,
#   529.66,
#   457.17,
#   219): 'RAV4',
#  (2018,
#   19698,
#   'Automatic',
#   21893,
#   'Gasoline',
#   43.5,
#   359.79,
#   316.98,
#   150): 'RAV4',
#  (2015,
#   15298,
#   'Semi-Auto',
#   21232,
#   'Gasoline',
#   39.2,
#   279.43,
#   250.65,
#   150): 'RAV4',
#  (2019, 37440, 'Automatic', 2764, 'Hybrid', 51.1, 683.86, 584.43, 219): 'RAV4',
#  (2017,
#   19998,
#   'Automatic',
#   10028,
#   'Gasoline',
#   43.5,
#   365.27,
#   321.5,
#   150): 'RAV4',
#  (2016, 13495, 'Manual', 30124, 'Diesel', 60.1, 246.49, 223.47, 150): 'RAV4',
#  (2017, 15995, 'Manual', 59205, 'Diesel', 60.1, 292.16, 261.16, 150): 'RAV4',
#  (2014,
#   12998,
#   'Automatic',
#   41389,
#   'Diesel',
#   42.2,
#   237.41,
#   215.98,
#   177): 'RAV4',
#  (2016, 13998, 'Manual', 36030, 'Diesel', 60.1, 255.68, 231.06, 150): 'RAV4',
#  (2017, 14998, 'Manual', 32087, 'Diesel', 60.1, 273.95, 246.13, 150): 'RAV4',
#  (2019, 34990, 'Automatic', 5000, 'Hybrid', 49.6, 639.11, 547.49, 219): 'RAV4',
#  (2015, 9998, 'Manual', 81503, 'Diesel', 57.6, 182.62, 170.76, 150): 'RAV4',
#  (2017, 16295, 'Manual', 34633, 'Diesel', 60.1, 297.64, 265.68, 150): 'RAV4',
#  (2015, 13495, 'Manual', 28308, 'Diesel', 53.0, 246.49, 223.47, 150): 'RAV4',
#  (2016, 15200, 'Manual', 27232, 'Diesel', 60.1, 277.64, 249.18, 150): 'RAV4',
#  (2019, 29570, 'Automatic', 7823, 'Hybrid', 51.1, 540.11, 465.79, 219): 'RAV4',
#  (2017, 14498, 'Manual', 41201, 'Diesel', 60.1, 264.81, 238.59, 150): 'RAV4',
#  (2019,
#   27570,
#   'Automatic',
#   15581,
#   'Hybrid',
#   52.3,
#   503.58,
#   435.64,
#   219): 'RAV4',
#  (2019, 34990, 'Automatic', 5660, 'Hybrid', 49.6, 639.11, 547.49, 219): 'RAV4',
#  (2015,
#   14490,
#   'Automatic',
#   59454,
#   'Diesel',
#   42.2,
#   264.67,
#   238.47,
#   177): 'RAV4',
#  (2017, 14495, 'Manual', 37893, 'Diesel', 60.1, 264.76, 238.55, 150): 'RAV4',
#  (2019, 29995, 'Automatic', 9709, 'Hybrid', 49.6, 547.87, 472.2, 219): 'RAV4',
#  (2014, 9798, 'Manual', 77512, 'Diesel', 53.0, 178.97, 167.74, 150): 'RAV4',
#  (2016, 14498, 'Manual', 23485, 'Diesel', 60.1, 264.81, 238.59, 150): 'RAV4',
#  (2016, 14998, 'Manual', 28083, 'Diesel', 60.1, 273.95, 246.13, 150): 'RAV4',
#  (2014,
#   11998,
#   'Semi-Auto',
#   51258,
#   'Gasoline',
#   39.2,
#   219.15,
#   200.91,
#   150): 'RAV4',
#  (2014, 10995, 'Manual', 59627, 'Diesel', 57.6, 200.83, 185.79, 150): 'RAV4',
#  (2019,
#   27293,
#   'Automatic',
#   19814,
#   'Hybrid',
#   49.6,
#   498.52,
#   431.47,
#   219): 'RAV4',
#  (2014, 9998, 'Manual', 78650, 'Diesel', 49.6, 182.62, 170.76, 177): 'RAV4',
#  (2013,
#   10990,
#   'Automatic',
#   45000,
#   'Diesel',
#   42.2,
#   200.74,
#   185.71,
#   177): 'RAV4',
#  (2016, 13995, 'Manual', 38338, 'Diesel', 60.1, 255.63, 231.01, 150): 'RAV4',
#  (2019, 31995, 'Automatic', 11970, 'Hybrid', 49.6, 584.4, 502.35, 219): 'RAV4',
#  (2019, 31995, 'Automatic', 11728, 'Hybrid', 49.6, 584.4, 502.35, 219): 'RAV4',
#  (2016, 14295, 'Manual', 31887, 'Diesel', 60.1, 261.11, 235.53, 150): 'RAV4',
#  (2015, 11495, 'Manual', 44652, 'Diesel', 53.0, 209.96, 193.33, 150): 'RAV4',
#  (2014, 10999, 'Manual', 57942, 'Diesel', 53.0, 200.9, 185.85, 150): 'RAV4',
#  (2017, 13998, 'Manual', 32815, 'Diesel', 60.1, 255.68, 231.06, 150): 'RAV4',
#  (2014, 9780, 'Manual', 88870, 'Diesel', 57.6, 178.64, 167.47, 150): 'RAV4',
#  (2015, 10995, 'Manual', 63000, 'Diesel', 49.6, 200.83, 185.79, 177): 'RAV4',
#  (2015,
#   12480,
#   'Automatic',
#   45848,
#   'Diesel',
#   42.2,
#   227.95,
#   208.17,
#   177): 'RAV4',
#  (2016, 12498, 'Manual', 49814, 'Diesel', 60.1, 228.28, 208.44, 150): 'RAV4',
#  (2013, 9990, 'Manual', 59934, 'Diesel', 49.6, 182.47, 170.64, 177): 'RAV4',
#  (2017, 16675, 'Manual', 22565, 'Diesel', 60.1, 304.58, 271.41, 150): 'RAV4',
#  (2019, 29000, 'Automatic', 10853, 'Hybrid', 51.1, 529.7, 457.2, 219): 'RAV4',
#  (2016, 13000, 'Manual', 56437, 'Diesel', 60.1, 237.45, 216.01, 150): 'RAV4',
#  (2013, 9945, 'Manual', 62541, 'Diesel', 49.6, 181.65, 169.96, 177): 'RAV4',
#  (2019, 33880, 'Automatic', 7576, 'Hybrid', 49.6, 618.83, 530.76, 219): 'RAV4',
#  (2019, 27790, 'Automatic', 16360, 'Hybrid', 51.1, 507.6, 438.96, 219): 'RAV4',
#  (2013, 9250, 'Manual', 70964, 'Diesel', 49.6, 168.96, 159.48, 177): 'RAV4',
#  (2014, 11000, 'Manual', 52561, 'Diesel', 57.6, 200.92, 185.86, 150): 'RAV4',
#  (2015, 13200, 'Manual', 10763, 'Diesel', 57.6, 241.1, 219.03, 150): 'RAV4',
#  (2019, 29980, 'Automatic', 6691, 'Hybrid', 49.6, 547.6, 471.97, 219): 'RAV4',
#  (2017,
#   19480,
#   'Automatic',
#   10985,
#   'Gasoline',
#   43.5,
#   355.81,
#   313.69,
#   150): 'RAV4',
#  (2017,
#   18490,
#   'Automatic',
#   30305,
#   'Gasoline',
#   43.5,
#   337.73,
#   298.77,
#   150): 'RAV4',
#  (2017,
#   18490,
#   'Automatic',
#   30724,
#   'Gasoline',
#   43.5,
#   337.73,
#   298.77,
#   150): 'RAV4',
#  (2014, 10490, 'Manual', 67712, 'Diesel', 53.0, 191.6, 178.18, 150): 'RAV4',
#  (2016,
#   16980,
#   'Automatic',
#   24560,
#   'Gasoline',
#   43.5,
#   310.15,
#   276.01,
#   150): 'RAV4',
#  (2014, 10995, 'Manual', 49429, 'Diesel', 53.0, 200.83, 185.79, 150): 'RAV4',
#  (2019, 33595, 'Automatic', 8000, 'Hybrid', 49.6, 613.63, 526.47, 219): 'RAV4',
#  (2016, 14995, 'Manual', 27762, 'Diesel', 60.1, 273.89, 246.09, 150): 'RAV4',
#  (2016, 14295, 'Manual', 22262, 'Diesel', 60.1, 261.11, 235.53, 150): 'RAV4',
#  (2017,
#   17390,
#   'Automatic',
#   28546,
#   'Gasoline',
#   43.5,
#   317.64,
#   282.19,
#   150): 'RAV4',
#  (2016, 16980, 'Manual', 19570, 'Diesel', 60.1, 310.15, 276.01, 150): 'RAV4',
#  (2017, 12998, 'Manual', 57423, 'Diesel', 60.1, 237.41, 215.98, 150): 'RAV4',
#  (2016, 13290, 'Manual', 38655, 'Diesel', 60.1, 242.75, 220.38, 150): 'RAV4',
#  (2017,
#   19000,
#   'Automatic',
#   16000,
#   'Gasoline',
#   43.5,
#   347.04,
#   306.46,
#   150): 'RAV4',
#  (2020, 31790, 'Automatic', 1652, 'Hybrid', 49.6, 580.66, 481.34, 219): 'RAV4',
#  (2016, 15990, 'Manual', 20553, 'Diesel', 60.1, 292.07, 261.08, 150): 'RAV4',
#  (2015,
#   13690,
#   'Automatic',
#   50417,
#   'Diesel',
#   42.2,
#   250.05,
#   226.41,
#   177): 'RAV4',
#  (2013, 11995, 'Manual', 29445, 'Diesel', 49.6, 219.09, 200.86, 177): 'RAV4',
#  (2018,
#   22995,
#   'Automatic',
#   13833,
#   'Gasoline',
#   43.5,
#   420.01,
#   366.68,
#   150): 'RAV4',
#  (2016,
#   13610,
#   'Automatic',
#   60841,
#   'Gasoline',
#   43.5,
#   248.59,
#   225.21,
#   150): 'RAV4',
#  (2017,
#   20990,
#   'Automatic',
#   17681,
#   'Gasoline',
#   43.5,
#   383.39,
#   336.46,
#   150): 'RAV4',
#  (2016, 14995, 'Manual', 25801, 'Diesel', 60.1, 273.89, 246.09, 150): 'RAV4',
#  (2015,
#   11795,
#   'Automatic',
#   48125,
#   'Diesel',
#   42.2,
#   215.44,
#   197.85,
#   177): 'RAV4',
#  (2017, 15295, 'Manual', 39624, 'Diesel', 60.1, 279.37, 250.61, 150): 'RAV4',
#  (2018,
#   19990,
#   'Automatic',
#   23165,
#   'Gasoline',
#   43.5,
#   365.13,
#   321.38,
#   150): 'RAV4',
#  (2015, 9547, 'Manual', 60148, 'Diesel', 57.6, 174.38, 163.96, 150): 'RAV4',
#  (2020, 33995, 'Automatic', 1500, 'Hybrid', 51.1, 620.94, 513.33, 219): 'RAV4',
#  (2017, 15995, 'Manual', 22864, 'Diesel', 60.1, 292.16, 261.16, 150): 'RAV4',
#  (2016, 14499, 'Manual', 32070, 'Diesel', 60.1, 264.83, 238.61, 150): 'RAV4',
#  (2017, 14450, 'Manual', 61000, 'Diesel', 60.1, 263.94, 237.87, 150): 'RAV4',
#  (2016, 13900, 'Manual', 14152, 'Diesel', 60.1, 253.89, 229.58, 150): 'RAV4',
#  (2016, 13790, 'Manual', 37849, 'Diesel', 60.1, 251.88, 227.92, 150): 'RAV4',
#  (2016, 14288, 'Manual', 30100, 'Diesel', 60.1, 260.98, 235.43, 150): 'RAV4',
#  (2015, 13499, 'Manual', 18200, 'Diesel', 57.6, 246.57, 223.53, 150): 'RAV4',
#  (2017, 16711, 'Manual', 17000, 'Diesel', 60.1, 305.23, 271.95, 150): 'RAV4',
#  (2015,
#   13330,
#   'Automatic',
#   36426,
#   'Gasoline',
#   39.2,
#   243.48,
#   220.99,
#   150): 'RAV4',
#  (2016, 13999, 'Manual', 31457, 'Diesel', 60.1, 255.7, 231.07, 150): 'RAV4',
#  (2014, 12495, 'Manual', 30726, 'Diesel', 53.0, 228.23, 208.4, 150): 'RAV4',
#  (2017, 18562, 'Manual', 11556, 'Diesel', 60.1, 339.04, 299.85, 150): 'RAV4',
#  (2017, 15293, 'Manual', 26191, 'Diesel', 60.1, 279.33, 250.58, 150): 'RAV4',
#  (2019, 33626, 'Automatic', 7191, 'Hybrid', 49.6, 614.2, 526.93, 219): 'RAV4',
#  (2015, 12711, 'Manual', 56203, 'Diesel', 53.0, 232.17, 211.66, 150): 'RAV4',
#  (2013, 10311, 'Manual', 57299, 'Diesel', 49.6, 188.34, 175.48, 177): 'RAV4',
#  (2015, 12232, 'Manual', 46000, 'Diesel', 53.0, 223.42, 204.44, 150): 'RAV4',
#  (2019, 32860, 'Automatic', 4271, 'Hybrid', 49.6, 600.2, 515.39, 219): 'RAV4',
#  (2019, 33892, 'Automatic', 7735, 'Hybrid', 49.6, 619.05, 530.94, 219): 'RAV4',
#  (2017, 15200, 'Manual', 47026, 'Diesel', 60.1, 277.64, 249.18, 150): 'RAV4',
#  (2017,
#   17995,
#   'Automatic',
#   35509,
#   'Gasoline',
#   43.5,
#   328.69,
#   291.31,
#   150): 'RAV4',
#  (2017,
#   20182,
#   'Automatic',
#   25714,
#   'Gasoline',
#   43.5,
#   368.63,
#   324.28,
#   150): 'RAV4',
#  (2013, 10191, 'Manual', 54115, 'Diesel', 49.6, 186.14, 173.67, 177): 'RAV4',
#  (2017, 14897, 'Manual', 37100, 'Diesel', 60.1, 272.1, 244.61, 150): 'RAV4',
#  (2015,
#   14999,
#   'Automatic',
#   33481,
#   'Diesel',
#   42.2,
#   273.96,
#   246.15,
#   177): 'RAV4',
#  (2014, 11990, 'Manual', 34050, 'Diesel', 53.0, 219.0, 200.79, 150): 'RAV4',
#  (2015, 11999, 'Manual', 64609, 'Diesel', 53.0, 219.17, 200.92, 150): 'RAV4',
#  (2017, 15999, 'Manual', 27170, 'Diesel', 60.1, 292.23, 261.22, 150): 'RAV4',
#  (2017, 14500, 'Manual', 33432, 'Diesel', 60.1, 264.85, 238.62, 150): 'RAV4',
#  (2019, 29550, 'Automatic', 8357, 'Hybrid', 49.6, 539.75, 465.49, 219): 'RAV4',
#  (2017, 14695, 'Manual', 40376, 'Diesel', 60.1, 268.41, 241.56, 150): 'RAV4',
#  (2017,
#   18995,
#   'Automatic',
#   21676,
#   'Gasoline',
#   43.5,
#   346.95,
#   306.38,
#   150): 'RAV4',
#  (2016,
#   15495,
#   'Automatic',
#   43000,
#   'Gasoline',
#   43.5,
#   283.02,
#   253.62,
#   150): 'RAV4',
#  (2018, 17590, 'Manual', 29883, 'Diesel', 60.1, 321.29, 285.2, 150): 'RAV4',
#  (2019, 30000, 'Automatic', 6677, 'Hybrid', 49.6, 547.96, 472.27, 219): 'RAV4',
#  (2017,
#   19999,
#   'Automatic',
#   13069,
#   'Gasoline',
#   43.5,
#   365.29,
#   321.52,
#   150): 'RAV4',
#  (2014,
#   14295,
#   'Semi-Auto',
#   31306,
#   'Gasoline',
#   39.2,
#   261.11,
#   235.53,
#   150): 'RAV4',
#  (2017, 15450, 'Manual', 19200, 'Diesel', 60.1, 282.2, 252.94, 150): 'RAV4',
#  (2013, 12495, 'Automatic', 30524, 'Diesel', 42.2, 228.23, 208.4, 177): 'RAV4',
#  (2016,
#   19490,
#   'Automatic',
#   6254,
#   'Gasoline',
#   43.5,
#   355.99,
#   313.84,
#   150): 'RAV4',
#  (2016, 14650, 'Manual', 22080, 'Diesel', 60.1, 267.59, 240.88, 150): 'RAV4',
#  (2014, 10995, 'Manual', 41411, 'Diesel', 57.6, 200.83, 185.79, 150): 'RAV4',
#  (2017,
#   18000,
#   'Automatic',
#   33128,
#   'Gasoline',
#   43.5,
#   328.78,
#   291.38,
#   150): 'RAV4',
#  (2016, 14010, 'Manual', 47000, 'Diesel', 60.1, 255.9, 231.24, 150): 'RAV4',
#  (2017, 16000, 'Manual', 38000, 'Diesel', 60.1, 292.25, 261.23, 150): 'RAV4',
#  (2013, 10500, 'Manual', 57962, 'Diesel', 49.6, 191.79, 178.33, 177): 'RAV4',
#  (2017, 14795, 'Manual', 47362, 'Diesel', 60.1, 270.24, 243.07, 150): 'RAV4',
#  (2017, 15995, 'Manual', 18000, 'Diesel', 60.1, 292.16, 261.16, 150): 'RAV4',
#  (2017, 15750, 'Manual', 32804, 'Diesel', 60.1, 287.68, 257.47, 150): 'RAV4',
#  (2013, 12295, 'Manual', 43573, 'Diesel', 57.6, 224.57, 205.38, 150): 'RAV4',
#  (2017, 15895, 'Manual', 42810, 'Diesel', 60.1, 290.33, 259.65, 150): 'RAV4',
#  (2017, 17295, 'Manual', 31057, 'Diesel', 60.1, 315.9, 280.76, 150): 'RAV4',
#  (2016, 15995, 'Manual', 37531, 'Diesel', 60.1, 292.16, 261.16, 150): 'RAV4',
#  (2015, 11395, 'Manual', 66973, 'Diesel', 57.6, 208.14, 191.82, 150): 'RAV4',
#  (2016,
#   20495,
#   'Automatic',
#   32754,
#   'Gasoline',
#   43.5,
#   374.35,
#   328.99,
#   150): 'RAV4',
#  (2019,
#   32495,
#   'Automatic',
#   12740,
#   'Hybrid',
#   49.6,
#   593.54,
#   509.88,
#   219): 'RAV4',
#  (2018,
#   22346,
#   'Automatic',
#   10116,
#   'Gasoline',
#   48.7,
#   408.16,
#   356.9,
#   150): 'RAV4',
#  (2015, 11804, 'Manual', 38999, 'Diesel', 57.6, 215.61, 197.98, 150): 'RAV4',
#  (2020, 36500, 'Automatic', 1114, 'Hybrid', 49.6, 666.69, 549.68, 219): 'RAV4',
#  (2015, 10500, 'Manual', 52462, 'Diesel', 57.6, 191.79, 178.33, 150): 'RAV4',
#  (2015,
#   14000,
#   'Automatic',
#   47291,
#   'Diesel',
#   42.2,
#   255.72,
#   231.09,
#   177): 'RAV4',
#  (2017,
#   19000,
#   'Automatic',
#   25981,
#   'Gasoline',
#   43.5,
#   347.04,
#   306.46,
#   150): 'RAV4',
#  (2016, 13599, 'Manual', 43733, 'Diesel', 60.1, 248.39, 225.04, 150): 'RAV4',
#  (2016,
#   16217,
#   'Automatic',
#   24431,
#   'Gasoline',
#   43.5,
#   296.21,
#   264.51,
#   150): 'RAV4',
#  (2019, 29903, 'Automatic', 9000, 'Hybrid', 51.1, 546.19, 470.81, 219): 'RAV4',
#  (2013,
#   11270,
#   'Automatic',
#   67000,
#   'Diesel',
#   42.2,
#   205.85,
#   189.93,
#   177): 'RAV4',
#  (2016,
#   17750,
#   'Automatic',
#   18863,
#   'Gasoline',
#   43.5,
#   324.21,
#   287.61,
#   150): 'RAV4',
#  (2017,
#   20999,
#   'Automatic',
#   11500,
#   'Gasoline',
#   43.5,
#   383.56,
#   336.59,
#   150): 'RAV4',
#  (2017, 17995, 'Manual', 36000, 'Diesel', 60.1, 328.69, 291.31, 150): 'RAV4',
#  (2017,
#   18991,
#   'Automatic',
#   33900,
#   'Gasoline',
#   43.5,
#   346.88,
#   306.32,
#   150): 'RAV4',
#  (2013, 9991, 'Manual', 63808, 'Diesel', 49.6, 182.49, 170.65, 177): 'RAV4',
#  (2019,
#   29900,
#   'Automatic',
#   16885,
#   'Hybrid',
#   49.6,
#   546.14,
#   470.77,
#   219): 'RAV4',
#  (2014, 10201, 'Manual', 58941, 'Diesel', 53.0, 186.33, 173.82, 150): 'RAV4',
#  (2013,
#   13495,
#   'Semi-Auto',
#   34201,
#   'Gasoline',
#   39.2,
#   246.49,
#   223.47,
#   150): 'RAV4',
#  (2016,
#   17695,
#   'Automatic',
#   26650,
#   'Gasoline',
#   43.5,
#   323.21,
#   286.79,
#   150): 'RAV4',
#  (2019,
#   30999,
#   'Automatic',
#   10768,
#   'Hybrid',
#   51.1,
#   566.21,
#   487.33,
#   219): 'RAV4',
#  (2017,
#   19995,
#   'Automatic',
#   15375,
#   'Gasoline',
#   43.5,
#   365.22,
#   321.46,
#   150): 'RAV4',
#  (2013, 8990, 'Manual', 70400, 'Diesel', 49.6, 164.21, 155.56, 177): 'RAV4',
#  (2014, 10495, 'Manual', 52429, 'Diesel', 53.0, 191.7, 178.25, 150): 'RAV4',
#  (2014, 10244, 'Manual', 56822, 'Diesel', 57.6, 187.11, 174.47, 150): 'RAV4',
#  (2019, 35955, 'Automatic', 2984, 'Hybrid', 49.6, 656.74, 562.04, 219): 'RAV4',
#  (2017,
#   18229,
#   'Automatic',
#   23658,
#   'Gasoline',
#   43.5,
#   332.96,
#   294.84,
#   150): 'RAV4',
#  (2010, 6250, 'Manual', 91500, 'Diesel', 48.7, 114.16, 114.26, 177): 'RAV4',
#  (2011, 7500, 'Automatic', 87200, 'Diesel', 39.8, 136.99, 133.1, 177): 'RAV4',
#  (2007, 4395, 'Manual', 73000, 'Diesel', 42.8, 80.28, 86.3, 177): 'RAV4',
#  (2019,
#   28222,
#   'Automatic',
#   10570,
#   'Hybrid',
#   49.6,
#   515.49,
#   445.47,
#   219): 'RAV4',
#  (2012, 9995, 'Manual', 42226, 'Diesel', 47.1, 182.56, 170.71, 177): 'RAV4',
#  (2005, 3695, 'Manual', 105000, 'Diesel', 39.8, 67.49, 75.75, 150): 'RAV4',
#  (2005, 3495, 'Manual', 99000, 'Diesel', 39.8, 63.84, 72.73, 150): 'RAV4',
#  (2015,
#   13800,
#   'Automatic',
#   31015,
#   'Diesel',
#   42.2,
#   252.06,
#   228.07,
#   177): 'RAV4',
#  (2014,
#   11450,
#   'Automatic',
#   52079,
#   'Diesel',
#   42.2,
#   209.14,
#   192.65,
#   177): 'RAV4',
#  (2017, 15574, 'Manual', 32837, 'Diesel', 60.1, 284.47, 254.81, 150): 'RAV4',
#  (2017,
#   17995,
#   'Automatic',
#   31250,
#   'Gasoline',
#   43.5,
#   328.69,
#   291.31,
#   150): 'RAV4',
#  (2015,
#   15199,
#   'Automatic',
#   32611,
#   'Gasoline',
#   39.2,
#   277.62,
#   249.16,
# ...
#   219.0,
#   200.79,
#   111): 'Yaris',
#  (2016, 8570, 'Manual', 29466, 'Gasoline', 55.0, 156.54, 149.23, 99): 'Yaris',
#  (2018, 9990, 'Manual', 8011, 'Gasoline', 58.9, 182.47, 170.64, 111): 'Yaris',
#  (2014, 4995, 'Manual', 53854, 'Gasoline', 52.3, 91.24, 95.34, 99): 'Yaris',
#  (2016, 6495, 'Manual', 25345, 'Gasoline', 66.0, 118.63, 117.95, 72): 'Yaris',
#  (2016,
#   13870,
#   'Automatic',
#   15821,
#   'Hybrid',
#   78.0,
#   253.34,
#   229.13,
#   116): 'Yaris',
#  (2019, 11998, 'Manual', 1404, 'Gasoline', 47.9, 219.15, 200.91, 111): 'Yaris',
#  (2016, 8070, 'Manual', 32685, 'Gasoline', 66.0, 147.4, 141.7, 72): 'Yaris',
#  (2014,
#   10460,
#   'Automatic',
#   29847,
#   'Hybrid',
#   78.0,
#   191.06,
#   177.72,
#   116): 'Yaris',
#  (2019, 12570, 'Manual', 8579, 'Gasoline', 47.9, 229.6, 209.53, 111): 'Yaris',
#  (2017,
#   12570,
#   'Automatic',
#   26758,
#   'Hybrid',
#   76.3,
#   229.6,
#   209.53,
#   116): 'Yaris',
#  (2018, 10790, 'Manual', 16424, 'Gasoline', 58.9, 197.08, 182.7, 111): 'Yaris',
#  (2019, 11490, 'Manual', 8793, 'Gasoline', 47.9, 209.87, 193.25, 111): 'Yaris',
#  (2018,
#   10670,
#   'Manual',
#   16795,
#   'Gasoline',
#   58.9,
#   194.89,
#   180.89,
#   111): 'Yaris',
#  (2017, 10998, 'Manual', 9386, 'Gasoline', 56.5, 200.88, 185.83, 111): 'Yaris',
#  (2017, 9298, 'Manual', 35121, 'Gasoline', 55.0, 169.83, 160.21, 99): 'Yaris',
#  (2013, 5998, 'Manual', 43364, 'Gasoline', 51.4, 109.56, 110.46, 99): 'Yaris',
#  (2017, 10498, 'Manual', 18693, 'Gasoline', 56.5, 191.75, 178.3, 111): 'Yaris',
#  (2018, 10498, 'Manual', 12985, 'Gasoline', 58.9, 191.75, 178.3, 111): 'Yaris',
#  (2017, 10498, 'Manual', 5760, 'Gasoline', 58.9, 191.75, 178.3, 111): 'Yaris',
#  (2017,
#   9998,
#   'Automatic',
#   31728,
#   'Gasoline',
#   58.0,
#   182.62,
#   170.76,
#   99): 'Yaris',
#  (2017, 8998, 'Manual', 23533, 'Gasoline', 58.0, 164.35, 155.69, 99): 'Yaris',
#  (2017, 8998, 'Manual', 21198, 'Gasoline', 58.0, 164.35, 155.69, 99): 'Yaris',
#  (2017,
#   12595,
#   'Automatic',
#   15107,
#   'Hybrid',
#   76.3,
#   230.05,
#   209.91,
#   116): 'Yaris',
#  (2016,
#   13570,
#   'Automatic',
#   18629,
#   'Hybrid',
#   78.0,
#   247.86,
#   224.6,
#   116): 'Yaris',
#  (2018,
#   12990,
#   'Automatic',
#   13904,
#   'Hybrid',
#   76.3,
#   237.27,
#   215.86,
#   116): 'Yaris',
#  (2018, 10495, 'Manual', 22268, 'Gasoline', 58.9, 191.7, 178.25, 111): 'Yaris',
#  (2013, 4998, 'Manual', 56996, 'Gasoline', 58.9, 91.29, 95.39, 72): 'Yaris',
#  (2017, 9495, 'Manual', 9626, 'Gasoline', 58.9, 173.43, 163.18, 111): 'Yaris',
#  (2017,
#   12495,
#   'Automatic',
#   22269,
#   'Hybrid',
#   76.3,
#   228.23,
#   208.4,
#   116): 'Yaris',
#  (2016, 9798, 'Manual', 17873, 'Gasoline', 55.0, 178.97, 167.74, 99): 'Yaris',
#  (2019, 11990, 'Manual', 7069, 'Gasoline', 47.9, 219.0, 200.79, 111): 'Yaris',
#  (2017, 10570, 'Manual', 8963, 'Gasoline', 55.0, 193.07, 179.38, 99): 'Yaris',
#  (2017,
#   13070,
#   'Automatic',
#   15871,
#   'Hybrid',
#   86.0,
#   238.73,
#   217.07,
#   116): 'Yaris',
#  (2018,
#   10990,
#   'Manual',
#   20789,
#   'Gasoline',
#   56.5,
#   200.74,
#   185.71,
#   111): 'Yaris',
#  (2015,
#   10360,
#   'Automatic',
#   8370,
#   'Gasoline',
#   55.0,
#   189.23,
#   176.22,
#   99): 'Yaris',
#  (2019, 12695, 'Manual', 3745, 'Gasoline', 47.9, 231.88, 211.41, 111): 'Yaris',
#  (2017,
#   12995,
#   'Automatic',
#   12327,
#   'Hybrid',
#   76.3,
#   237.36,
#   215.94,
#   116): 'Yaris',
#  (2015,
#   11698,
#   'Automatic',
#   21076,
#   'Hybrid',
#   78.0,
#   213.67,
#   196.39,
#   116): 'Yaris',
#  (2019, 11870, 'Manual', 8324, 'Gasoline', 47.9, 216.81, 198.98, 111): 'Yaris',
#  (2016, 8510, 'Manual', 26889, 'Gasoline', 55.0, 155.44, 148.33, 99): 'Yaris',
#  (2017,
#   11498,
#   'Automatic',
#   19495,
#   'Gasoline',
#   60.1,
#   210.02,
#   193.37,
#   111): 'Yaris',
#  (2018, 10998, 'Manual', 9053, 'Gasoline', 58.9, 200.88, 185.83, 111): 'Yaris',
#  (2018, 9498, 'Manual', 27098, 'Gasoline', 58.9, 173.49, 163.22, 111): 'Yaris',
#  (2015, 7298, 'Manual', 32358, 'Gasoline', 55.0, 133.3, 130.06, 99): 'Yaris',
#  (2017, 9495, 'Manual', 12971, 'Gasoline', 66.0, 173.43, 163.18, 72): 'Yaris',
#  (2019, 11875, 'Manual', 8204, 'Gasoline', 47.9, 216.9, 199.05, 111): 'Yaris',
#  (2017,
#   11495,
#   'Automatic',
#   30613,
#   'Hybrid',
#   86.0,
#   209.96,
#   193.33,
#   116): 'Yaris',
#  (2018,
#   10995,
#   'Manual',
#   10601,
#   'Gasoline',
#   58.9,
#   200.83,
#   185.79,
#   111): 'Yaris',
#  (2015,
#   10495,
#   'Automatic',
#   37774,
#   'Hybrid',
#   78.0,
#   191.7,
#   178.25,
#   116): 'Yaris',
#  (2017, 8498, 'Manual', 26710, 'Gasoline', 58.0, 155.22, 148.15, 99): 'Yaris',
#  (2015, 6998, 'Manual', 45357, 'Gasoline', 55.0, 127.82, 125.54, 99): 'Yaris',
#  (2013,
#   8698,
#   'Automatic',
#   39963,
#   'Hybrid',
#   76.3,
#   158.87,
#   151.16,
#   116): 'Yaris',
#  (2017, 8498, 'Manual', 24868, 'Gasoline', 58.0, 155.22, 148.15, 99): 'Yaris',
#  (2017, 9998, 'Manual', 21255, 'Gasoline', 56.5, 182.62, 170.76, 111): 'Yaris',
#  (2015,
#   9998,
#   'Automatic',
#   29377,
#   'Hybrid',
#   78.0,
#   182.62,
#   170.76,
#   116): 'Yaris',
#  (2017, 8998, 'Manual', 20471, 'Gasoline', 58.0, 164.35, 155.69, 99): 'Yaris',
#  (2017, 9495, 'Manual', 35101, 'Gasoline', 55.0, 173.43, 163.18, 99): 'Yaris',
#  (2017, 8298, 'Manual', 29970, 'Gasoline', 58.0, 151.57, 145.13, 99): 'Yaris',
#  (2018,
#   11298,
#   'Manual',
#   15775,
#   'Gasoline',
#   56.5,
#   206.36,
#   190.36,
#   111): 'Yaris',
#  (2017, 9498, 'Manual', 34185, 'Gasoline', 56.5, 173.49, 163.22, 111): 'Yaris',
#  (2017, 7698, 'Manual', 43059, 'Gasoline', 58.0, 140.61, 136.09, 99): 'Yaris',
#  (2017, 9998, 'Manual', 18572, 'Gasoline', 58.9, 182.62, 170.76, 111): 'Yaris',
#  (2017, 9498, 'Manual', 44795, 'Gasoline', 56.5, 173.49, 163.22, 111): 'Yaris',
#  (2017, 10498, 'Manual', 23156, 'Gasoline', 56.5, 191.75, 178.3, 111): 'Yaris',
#  (2013, 4698, 'Manual', 76920, 'Gasoline', 58.9, 85.81, 90.87, 99): 'Yaris',
#  (2013, 5698, 'Manual', 57140, 'Gasoline', 51.4, 104.08, 105.94, 99): 'Yaris',
#  (2017, 8998, 'Manual', 22770, 'Gasoline', 58.0, 164.35, 155.69, 99): 'Yaris',
#  (2017, 8498, 'Manual', 18901, 'Gasoline', 58.0, 155.22, 148.15, 99): 'Yaris',
#  (2018, 10698, 'Manual', 14320, 'Gasoline', 58.9, 195.4, 181.31, 111): 'Yaris',
#  (2018,
#   10998,
#   'Manual',
#   14840,
#   'Gasoline',
#   56.5,
#   200.88,
#   185.83,
#   111): 'Yaris',
#  (2018,
#   10998,
#   'Manual',
#   12367,
#   'Gasoline',
#   56.5,
#   200.88,
#   185.83,
#   111): 'Yaris',
#  (2018, 9698, 'Manual', 12898, 'Gasoline', 58.9, 177.14, 166.24, 111): 'Yaris',
#  (2015, 6998, 'Manual', 34864, 'Gasoline', 66.0, 127.82, 125.54, 72): 'Yaris',
#  (2016, 7998, 'Manual', 40400, 'Gasoline', 55.0, 146.09, 140.61, 99): 'Yaris',
#  (2013, 4498, 'Manual', 81705, 'Gasoline', 58.9, 82.16, 87.85, 72): 'Yaris',
#  (2015,
#   10998,
#   'Automatic',
#   17140,
#   'Hybrid',
#   86.0,
#   200.88,
#   185.83,
#   116): 'Yaris',
#  (2017, 10798, 'Manual', 5100, 'Gasoline', 56.5, 197.23, 182.82, 111): 'Yaris',
#  (2017, 9498, 'Manual', 25130, 'Gasoline', 58.9, 173.49, 163.22, 111): 'Yaris',
#  (2017,
#   10995,
#   'Automatic',
#   10542,
#   'Gasoline',
#   60.1,
#   200.83,
#   185.79,
#   111): 'Yaris',
#  (2016, 8350, 'Manual', 63965, 'Gasoline', 55.0, 152.52, 145.92, 99): 'Yaris',
#  (2017, 8995, 'Manual', 19600, 'Gasoline', 58.9, 164.3, 155.64, 111): 'Yaris',
#  (2018,
#   10998,
#   'Manual',
#   15123,
#   'Gasoline',
#   56.5,
#   200.88,
#   185.83,
#   111): 'Yaris',
#  (2018, 10998, 'Manual', 6280, 'Gasoline', 58.9, 200.88, 185.83, 111): 'Yaris',
#  (2018, 10698, 'Manual', 7960, 'Gasoline', 58.9, 195.4, 181.31, 111): 'Yaris',
#  (2018,
#   10998,
#   'Manual',
#   24430,
#   'Gasoline',
#   56.5,
#   200.88,
#   185.83,
#   111): 'Yaris',
#  (2017, 7975, 'Manual', 23257, 'Gasoline', 58.0, 145.67, 140.26, 99): 'Yaris',
#  (2017, 9998, 'Manual', 17190, 'Gasoline', 58.9, 182.62, 170.76, 111): 'Yaris',
#  (2019,
#   12995,
#   'Automatic',
#   4320,
#   'Gasoline',
#   47.9,
#   237.36,
#   215.94,
#   111): 'Yaris',
#  (2016, 7498, 'Manual', 15203, 'Gasoline', 66.0, 136.95, 133.07, 72): 'Yaris',
#  (2014,
#   9998,
#   'Automatic',
#   18880,
#   'Hybrid',
#   86.0,
#   182.62,
#   170.76,
#   116): 'Yaris',
#  (2016, 7998, 'Manual', 32610, 'Gasoline', 58.0, 146.09, 140.61, 99): 'Yaris',
#  (2016, 7998, 'Manual', 48990, 'Gasoline', 55.0, 146.09, 140.61, 99): 'Yaris',
#  (2017, 10498, 'Manual', 10440, 'Gasoline', 56.5, 191.75, 178.3, 111): 'Yaris',
#  (2017, 8998, 'Manual', 19680, 'Gasoline', 58.9, 164.35, 155.69, 111): 'Yaris',
#  (2018,
#   10310,
#   'Manual',
#   10564,
#   'Gasoline',
#   58.9,
#   188.32,
#   175.46,
#   111): 'Yaris',
#  (2018,
#   12740,
#   'Automatic',
#   11324,
#   'Hybrid',
#   76.3,
#   232.7,
#   212.09,
#   116): 'Yaris',
#  (2018,
#   13555,
#   'Automatic',
#   15025,
#   'Hybrid',
#   67.3,
#   247.59,
#   224.38,
#   116): 'Yaris',
#  (2017, 9233, 'Manual', 21134, 'Gasoline', 58.9, 168.65, 159.23, 111): 'Yaris',
#  (2018,
#   10998,
#   'Automatic',
#   21608,
#   'Gasoline',
#   60.1,
#   200.88,
#   185.83,
#   111): 'Yaris',
#  (2015,
#   10998,
#   'Automatic',
#   7155,
#   'Hybrid',
#   86.0,
#   200.88,
#   185.83,
#   116): 'Yaris',
#  (2017, 9990, 'Manual', 17530, 'Gasoline', 56.5, 182.47, 170.64, 111): 'Yaris',
#  (2017, 8998, 'Manual', 21390, 'Gasoline', 58.9, 164.35, 155.69, 111): 'Yaris',
#  (2017,
#   10595,
#   'Automatic',
#   24410,
#   'Hybrid',
#   86.0,
#   193.52,
#   179.76,
#   116): 'Yaris',
#  (2016, 6990, 'Manual', 51926, 'Gasoline', 58.0, 127.68, 125.42, 99): 'Yaris',
#  (2013, 5999, 'Manual', 50000, 'Gasoline', 51.4, 109.57, 110.48, 99): 'Yaris',
#  (2019, 11310, 'Manual', 5400, 'Gasoline', 47.9, 206.58, 190.54, 111): 'Yaris',
#  (2019,
#   11495,
#   'Manual',
#   10994,
#   'Gasoline',
#   47.9,
#   209.96,
#   193.33,
#   111): 'Yaris',
#  (2016,
#   12995,
#   'Automatic',
#   13486,
#   'Hybrid',
#   78.0,
#   237.36,
#   215.94,
#   116): 'Yaris',
#  (2015,
#   9290,
#   'Automatic',
#   49063,
#   'Hybrid',
#   78.0,
#   169.69,
#   160.09,
#   116): 'Yaris',
#  (2014, 5990, 'Manual', 43681, 'Gasoline', 52.3, 109.41, 110.34, 99): 'Yaris',
#  (2015, 6490, 'Manual', 41000, 'Gasoline', 58.0, 118.54, 117.88, 99): 'Yaris',
#  (2014,
#   8295,
#   'Semi-Auto',
#   36218,
#   'Gasoline',
#   55.4,
#   151.51,
#   145.09,
#   99): 'Yaris',
#  (2017, 9495, 'Manual', 21690, 'Gasoline', 58.0, 173.43, 163.18, 99): 'Yaris',
#  (2015,
#   8695,
#   'Automatic',
#   29103,
#   'Gasoline',
#   58.0,
#   158.82,
#   151.12,
#   99): 'Yaris',
#  (2017, 9695, 'Manual', 16390, 'Gasoline', 58.0, 177.08, 166.19, 99): 'Yaris',
#  (2019, 12495, 'Manual', 5931, 'Gasoline', 47.9, 228.23, 208.4, 111): 'Yaris',
#  (2019, 12495, 'Manual', 8785, 'Gasoline', 47.9, 228.23, 208.4, 111): 'Yaris',
#  (2019, 12495, 'Manual', 4042, 'Gasoline', 47.9, 228.23, 208.4, 111): 'Yaris',
#  (2016, 8995, 'Manual', 33920, 'Gasoline', 55.0, 164.3, 155.64, 99): 'Yaris',
#  (2016,
#   12295,
#   'Automatic',
#   20775,
#   'Hybrid',
#   78.0,
#   224.57,
#   205.38,
#   116): 'Yaris',
#  (2017, 9695, 'Manual', 11792, 'Gasoline', 58.9, 177.08, 166.19, 111): 'Yaris',
#  (2018,
#   11995,
#   'Automatic',
#   6912,
#   'Hybrid',
#   76.3,
#   219.09,
#   200.86,
#   116): 'Yaris',
#  (2018, 12800, 'Automatic', 20436, 'Hybrid', 76.3, 233.8, 213.0, 116): 'Yaris',
#  (2015, 5850, 'Manual', 60257, 'Gasoline', 58.0, 106.85, 108.23, 99): 'Yaris',
#  (2019,
#   12850,
#   'Automatic',
#   4000,
#   'Gasoline',
#   47.9,
#   234.71,
#   213.75,
#   111): 'Yaris',
#  (2017,
#   11650,
#   'Automatic',
#   19736,
#   'Hybrid',
#   86.0,
#   212.79,
#   195.66,
#   116): 'Yaris',
#  (2014,
#   10495,
#   'Automatic',
#   49628,
#   'Hybrid',
#   78.0,
#   191.7,
#   178.25,
#   116): 'Yaris',
#  (2017,
#   12495,
#   'Automatic',
#   13356,
#   'Hybrid',
#   86.0,
#   228.23,
#   208.4,
#   116): 'Yaris',
#  (2016,
#   10495,
#   'Automatic',
#   33705,
#   'Hybrid',
#   86.0,
#   191.7,
#   178.25,
#   116): 'Yaris',
#  (2019, 11995, 'Manual', 7282, 'Gasoline', 47.9, 219.09, 200.86, 111): 'Yaris',
#  (2019, 12495, 'Manual', 8378, 'Gasoline', 47.9, 228.23, 208.4, 111): 'Yaris',
#  (2015, 7495, 'Manual', 29581, 'Gasoline', 58.0, 136.9, 133.03, 99): 'Yaris',
#  (2018,
#   13800,
#   'Automatic',
#   2500,
#   'Hybrid',
#   76.3,
#   252.06,
#   228.07,
#   116): 'Yaris',
#  (2017,
#   11998,
#   'Automatic',
#   14646,
#   'Hybrid',
#   86.0,
#   219.15,
#   200.91,
#   116): 'Yaris',
#  (2017, 9250, 'Manual', 23000, 'Gasoline', 58.9, 168.96, 159.48, 111): 'Yaris',
#  (2017,
#   11850,
#   'Automatic',
#   21000,
#   'Hybrid',
#   76.3,
#   216.45,
#   198.68,
#   116): 'Yaris',
#  (2014, 5444, 'Manual', 63475, 'Gasoline', 52.3, 99.44, 102.11, 99): 'Yaris',
#  (2017, 7995, 'Manual', 19000, 'Gasoline', 65.7, 146.03, 140.57, 72): 'Yaris',
#  (2018, 10550, 'Manual', 19377, 'Gasoline', 47.1, 192.7, 179.08, 111): 'Yaris',
#  (2016, 7495, 'Manual', 42752, 'Gasoline', 58.0, 136.9, 133.03, 99): 'Yaris',
#  (2017,
#   12995,
#   'Automatic',
#   30273,
#   'Hybrid',
#   78.0,
#   237.36,
#   215.94,
#   116): 'Yaris',
#  (2017, 9995, 'Manual', 12356, 'Gasoline', 58.0, 182.56, 170.71, 99): 'Yaris',
#  (2017, 10400, 'Manual', 8028, 'Gasoline', 58.9, 189.96, 176.82, 111): 'Yaris',
#  (2018, 13999, 'Manual', 12080, 'Hybrid', 67.3, 255.7, 231.07, 116): 'Yaris',
#  (2017,
#   10440,
#   'Automatic',
#   13000,
#   'Gasoline',
#   58.0,
#   190.69,
#   177.42,
#   99): 'Yaris',
#  (2017,
#   11700,
#   'Automatic',
#   35000,
#   'Hybrid',
#   78.0,
#   213.71,
#   196.42,
#   116): 'Yaris',
#  (2017, 9490, 'Manual', 23003, 'Gasoline', 55.0, 173.34, 163.1, 99): 'Yaris',
#  (2018, 12495, 'Manual', 12188, 'Gasoline', 56.5, 228.23, 208.4, 111): 'Yaris',
#  (2017, 9995, 'Manual', 25071, 'Gasoline', 58.0, 182.56, 170.71, 99): 'Yaris',
#  (2017, 9995, 'Manual', 18518, 'Gasoline', 58.0, 182.56, 170.71, 99): 'Yaris',
#  (2017,
#   12495,
#   'Automatic',
#   18927,
#   'Hybrid',
#   86.0,
#   228.23,
#   208.4,
#   116): 'Yaris',
#  (2018, 10995, 'Manual', 3100, 'Gasoline', 58.9, 200.83, 185.79, 111): 'Yaris',
#  (2017, 9495, 'Manual', 17111, 'Gasoline', 58.0, 173.43, 163.18, 99): 'Yaris',
#  (2018,
#   12000,
#   'Automatic',
#   37481,
#   'Hybrid',
#   76.3,
#   219.19,
#   200.94,
#   116): 'Yaris',
#  (2015,
#   11000,
#   'Automatic',
#   19228,
#   'Hybrid',
#   78.0,
#   200.92,
#   185.86,
#   116): 'Yaris',
#  (2017,
#   12995,
#   'Automatic',
#   20069,
#   'Hybrid',
#   78.0,
#   237.36,
#   215.94,
#   116): 'Yaris',
#  (2017, 9995, 'Manual', 22777, 'Gasoline', 58.9, 182.56, 170.71, 111): 'Yaris',
#  (2019, 12000, 'Manual', 1966, 'Gasoline', 47.9, 219.19, 200.94, 111): 'Yaris',
#  (2017,
#   11000,
#   'Automatic',
#   4159,
#   'Gasoline',
#   58.0,
#   200.92,
#   185.86,
#   99): 'Yaris',
#  (2016,
#   9995,
#   'Automatic',
#   28854,
#   'Gasoline',
#   55.0,
#   182.56,
#   170.71,
#   99): 'Yaris',
#  (2019, 13495, 'Manual', 3381, 'Gasoline', 47.9, 246.49, 223.47, 111): 'Yaris',
#  (2019, 12500, 'Manual', 1987, 'Gasoline', 47.9, 228.32, 208.48, 111): 'Yaris',
#  (2017, 9000, 'Manual', 19360, 'Gasoline', 58.0, 164.39, 155.72, 99): 'Yaris',
#  (2017,
#   10471,
#   'Automatic',
#   34408,
#   'Gasoline',
#   58.0,
#   191.26,
#   177.89,
#   99): 'Yaris',
#  (2017,
#   10590,
#   'Automatic',
#   40271,
#   'Hybrid',
#   86.0,
#   193.43,
#   179.68,
#   116): 'Yaris',
#  (2015,
#   9000,
#   'Automatic',
#   28417,
#   'Gasoline',
#   58.0,
#   164.39,
#   155.72,
#   99): 'Yaris',
#  (2017,
#   13250,
#   'Automatic',
#   9523,
#   'Hybrid',
#   76.3,
#   242.02,
#   219.78,
#   116): 'Yaris',
#  (2016, 8000, 'Manual', 34058, 'Gasoline', 58.0, 146.12, 140.64, 99): 'Yaris',
#  (2014, 7250, 'Manual', 19569, 'Gasoline', 52.3, 132.42, 129.34, 99): 'Yaris',
#  (2017, 9000, 'Manual', 12711, 'Gasoline', 58.0, 164.39, 155.72, 99): 'Yaris',
#  (2017,
#   13698,
#   'Automatic',
#   12706,
#   'Hybrid',
#   78.0,
#   250.2,
#   226.53,
#   116): 'Yaris',
#  (2016, 10698, 'Manual', 10698, 'Gasoline', 55.0, 195.4, 181.31, 99): 'Yaris',
#  (2019, 13000, 'Manual', 3746, 'Gasoline', 47.9, 237.45, 216.01, 111): 'Yaris',
#  (2019, 13000, 'Manual', 1378, 'Gasoline', 47.9, 237.45, 216.01, 111): 'Yaris',
#  (2019, 15500, 'Automatic', 1993, 'Hybrid', 76.3, 283.12, 253.7, 116): 'Yaris',
#  (2017,
#   11750,
#   'Automatic',
#   29823,
#   'Hybrid',
#   76.3,
#   214.62,
#   197.17,
#   116): 'Yaris',
#  (2015, 7190, 'Manual', 37000, 'Gasoline', 58.0, 131.33, 128.43, 99): 'Yaris',
#  (2017, 9398, 'Manual', 21329, 'Gasoline', 58.9, 171.66, 161.71, 111): 'Yaris',
#  (2016, 8298, 'Manual', 19948, 'Gasoline', 58.0, 151.57, 145.13, 99): 'Yaris',
#  (2017, 9500, 'Manual', 15100, 'Gasoline', 58.0, 173.52, 163.25, 99): 'Yaris',
#  (2013, 5180, 'Manual', 71402, 'Gasoline', 52.3, 94.62, 98.13, 99): 'Yaris',
#  (2019, 13000, 'Manual', 1000, 'Gasoline', 47.9, 237.45, 216.01, 111): 'Yaris',
#  (2017, 9000, 'Manual', 20175, 'Gasoline', 58.0, 164.39, 155.72, 99): 'Yaris',
#  (2017, 10000, 'Manual', 31215, 'Gasoline', 55.0, 182.65, 170.79, 99): 'Yaris',
#  (2018,
#   11000,
#   'Manual',
#   21668,
#   'Gasoline',
#   56.5,
#   200.92,
#   185.86,
#   111): 'Yaris',
#  (2018, 9500, 'Manual', 22788, 'Gasoline', 58.9, 173.52, 163.25, 111): 'Yaris',
#  ...}

# %%
user_input = tuple([2015,13998,"Manual",27469,"Gasoline",36.2,255.68,231.06,197])
recommended_models[user_input]
# Out:
# 'GT86'
